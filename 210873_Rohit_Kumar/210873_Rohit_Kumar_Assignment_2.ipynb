# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rng = np.random.RandomState()
x = 10 * rng.rand(50)
y = 3 * x - 4 + rng.randn(50)
plt.scatter(x, y);

# %%
rng = np.random.RandomState()
x_q = 10 * rng.rand(50)
y_q = x_q**2 - 5*x_q + 6 + rng.randn(50)
plt.scatter(x_q, y_q);

# %%
def loss(y_hat, y):
    l = np.abs((y_hat - y)**3/3) #cancels 3 out while taking pd
    return l.mean()

# %%
def loss_2(y_hat, y):
    m = np.abs((y_hat - y)) 
    return m.mean()

# %%
def loss_3(y_hat, y):
    n = (y_hat - y)**4/4
    return n.mean()

# %%
def loss_4(y_hat, y):
    o = np.abs((y_hat - y)**7)/7 
    return o.mean()

# %%
L_1=[]
L_2=[]
L_3=[]
L_4=[]
N=x.shape[0]

# %%
def forward_pass(x,m,c):
    return m*x+c

# %%
def forward_pass_q(x,a,b,e):
    return a*x**2 + b*x + e

# %%
m = np.random.randn(1)
a = np.random.randn(1)
b = np.random.randn(1)
m,a,b
# Out:
# (array([-0.19714164]), array([1.26886483]), array([-0.17020491]))

# %%
# Random Initialisation
m1 = np.random.randn(1)
c1 = np.random.randn(1)

# Hyperparameters
learningrate = 0.65*1e-6
numiter = 40000

for i in range(numiter):
    
    y_hat=forward_pass(x,m1,c1) # forward pass
    
    dm = (1.0/N) *  -np.sum(np.multiply(x,(y - (m1*x +c1))**2)) # gradient
    dc = (1.0/N) * -np.sum((y - (m1*x +c1))**2)
    
    m1 = m1 -learningrate * dm
    c1 = c1 - learningrate * dc
                           
    if i%5000==0:
        L_1.append(loss(y_hat,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_hat,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 5000
# no of iterations: 10000
# no of iterations: 15000
# no of iterations: 20000
# no of iterations: 25000
# no of iterations: 30000
# no of iterations: 35000

# %%
# Random Initialisation
m2 = np.random.randn(1)
c2 = np.random.randn(1)

# Hyperparameters
learningrate = 0.00001275
numiter = 40000

for i in range(numiter):
    
    y_hat_2=forward_pass(x,m2,c2) # forward pass
    
   
    dm = (1.0/N) *  -np.sum(x)  # Gradient
    dc = (1.0/N) * -np.sum(1)
    
    m2 = m2 -learningrate * dm
    c2 = c2 - learningrate * dc
                           
    if i%5000==0:
        L_2.append(loss_2(y_hat_2,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_hat_2,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 5000
# no of iterations: 10000
# no of iterations: 15000
# no of iterations: 20000
# no of iterations: 25000
# no of iterations: 30000
# no of iterations: 35000

# %%
# Random Initialisation
a1 = np.random.randn(1)
b1 = np.random.randn(1)
c1 = np.random.randn(1)

# Hyperparameters
learningrate = 0.0000000007
numiter = 50000

for i in range(numiter):
    # forward pass
    y_hat_3=forward_pass_q(x_q,a1,b1,c1)
    
    # Loss
   
    da = (1.0/N) *  -np.sum(np.multiply(x_q**2,(y_q - (a1*x_q**2 + b1*x_q +c1))**3))  # Gradient
    db = (1.0/N) *  -np.sum(np.multiply(x_q,(y_q - (a1*x_q**2 + b1*x_q +c1))**3))
    dc = (1.0/N) *  -np.sum((y_q - (a1*x_q**2 + b1*x_q +c1))**3)
    
    a1 = a1 - learningrate * da
    b1 = b1 - learningrate * db
    c1 = c1 - learningrate * dc

    if i%5000==0:
        L_3.append(loss_3(y_hat_3,y_q))
        print ("no of iterations:",i )
        plt.plot(x_q,y_q,'go')
        plt.plot(x_q,y_hat_3,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 5000
# no of iterations: 10000
# no of iterations: 15000
# no of iterations: 20000
# no of iterations: 25000
# no of iterations: 30000
# no of iterations: 35000
# no of iterations: 40000
# no of iterations: 45000

# %%
# Random Initialisation
a2 = np.random.randn(1)
b2 = np.random.randn(1)
c2 = np.random.randn(1)

# Hyperparameters
learningrate = 0.0000000000001
numiter = 50000

for i in range(numiter):
    # forward pass
    y_hat_4=forward_pass_q(x_q,a2,b2,c2)
    
    # Loss
   
    da = (1.0/N) *  -np.sum(np.multiply(x_q**2,(y_q - (a2*x_q**2 + b2*x_q +c2))**6)) # Gradient
    db = (1.0/N) *  -np.sum(np.multiply(x_q,(y_q - (a2*x_q**2 + b2*x_q +c2))**6))
    dc = (1.0/N) *  -np.sum((y_q - (a2*x_q**2 + b2*x_q +c2))**6)
    
    a2 = a2 - learningrate * da
    b2 = b2 - learningrate * db
    c2 = c2 - learningrate * dc

    if i%5000==0:
        L_4.append(loss_4(y_hat_4,y_q))
        print ("no of iterations:",i )
        plt.plot(x_q,y_q,'go')
        plt.plot(x_q,y_hat_4,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# C:\Users\actor\AppData\Local\Temp\ipykernel_34396\298437494.py:16: RuntimeWarning: overflow encountered in power
#   da = (1.0/N) *  -np.sum(np.multiply(x_q**2,(y_q - (a2*x_q**2 + b2*x_q +c2))**6)) # Gradient
# C:\Users\actor\AppData\Local\Temp\ipykernel_34396\298437494.py:17: RuntimeWarning: overflow encountered in power
#   db = (1.0/N) *  -np.sum(np.multiply(x_q,(y_q - (a2*x_q**2 + b2*x_q +c2))**6))
# C:\Users\actor\AppData\Local\Temp\ipykernel_34396\298437494.py:18: RuntimeWarning: overflow encountered in power
#   dc = (1.0/N) *  -np.sum((y_q - (a2*x_q**2 + b2*x_q +c2))**6)
# no of iterations: 5000
# no of iterations: 10000
# no of iterations: 15000
# no of iterations: 20000
# no of iterations: 25000
# no of iterations: 30000
# no of iterations: 35000
# no of iterations: 40000
# no of iterations: 45000

# %%
plt.plot(L_1,'green')
plt.plot(L_2,'blue')

# %%
plt.plot(L_3,'black')

# %%
plt.plot(L_4,'red')

# %%
m1,c1 #part a
# Out:
# (array([2.50640243]), array([-0.87081149]))

# %%
m2,c2 #part b
# Out:
# (array([3.8788774]), array([inf]))

# %%
a1,b1,c1 #part c
# Out:
# (array([0.35504508]), array([1.10058748]), array([-0.87081149]))

# %%
a2,b2,c2 #part d
# Out:
# (array([inf]), array([inf]), array([inf]))
