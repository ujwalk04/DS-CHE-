# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

def relu(z): # takes a numpy array as input and returns activated array
    a = np.maximum(0,z)
    return a

def initialize_params(layer_sizes): #takes a list of the layer sizes as input and returns initialized parameters
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

# %%
data = pd.read_csv('data.csv')
data
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
def forward_propagation(X_train, params): #takes input training features and parameters as input and returns a dictionary containining the numpy arrays of activations of all layers
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def compute_cost(values, Y_train): #takes true values and dictionary having activations of all layers as input and returns cost
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

# %%
def backward_propagation(params, values, X_train, Y_train): #takes parameters, activations, training set as input and returns gradients wrt parameters
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate): #takes parameters, gradients and learning rate as input and returns updated parameters
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

# %%
def model(X_train, Y_train, layer_sizes, num_iters, learning_rate): #trains the model
    params = initialize_params(layer_sizes)
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

def compute_accuracy(X_train, X_test, Y_train, Y_test, params): #compute accuracy on test and training data given learnt parameters
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):  #predict on new array X given learnt parameters
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2)           #split data into train and test sets in 80-20 ratio
layer_sizes = [13, 5, 5, 1]                                                       #set layer sizes, do not change the size of the first and last layer 
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03                                                              #set learning rate for gradient descent
params = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  #get training and test accuracy
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# Cost at iteration 1 = 288.9893466460413
#
# Cost at iteration 2 = 288.9498494070152
#
# Cost at iteration 3 = 288.91017491220293
#
# Cost at iteration 4 = 288.8702999382389
#
# Cost at iteration 5 = 288.8302001601102
#
# Cost at iteration 6 = 288.7898473960855
#
# Cost at iteration 7 = 288.74921392160314
#
# Cost at iteration 8 = 288.708265391338
#
# Cost at iteration 9 = 288.6669633104005
#
# Cost at iteration 10 = 288.62526606020003
#
# Cost at iteration 11 = 288.58312261820345
#
# Cost at iteration 12 = 288.54047675081705
#
# Cost at iteration 13 = 288.49727160309925
#
# Cost at iteration 14 = 288.45343375256687
#
# Cost at iteration 15 = 288.4088846862046
#
# Cost at iteration 16 = 288.36353851659163
#
# Cost at iteration 17 = 288.31729372088296
#
# Cost at iteration 18 = 288.2700287949008
#
# Cost at iteration 19 = 288.221603268981
#
# Cost at iteration 20 = 288.1718567689392
#
# Cost at iteration 21 = 288.12060359688775
#
# Cost at iteration 22 = 288.0676293475163
#
# Cost at iteration 23 = 288.0126760783832
#
# Cost at iteration 24 = 287.95544012159
#
# Cost at iteration 25 = 287.8955663757102
#
# Cost at iteration 26 = 287.8326154752747
#
# Cost at iteration 27 = 287.7660975356737
#
# Cost at iteration 28 = 287.69552888036486
#
# Cost at iteration 29 = 287.6202003479441
#
# Cost at iteration 30 = 287.53935900803486
#
# Cost at iteration 31 = 287.45190974962065
#
# Cost at iteration 32 = 287.3564053882748
#
# Cost at iteration 33 = 287.2512825108616
#
# Cost at iteration 34 = 287.1346189120116
#
# Cost at iteration 35 = 287.00402402168953
#
# Cost at iteration 36 = 286.8565160519909
#
# Cost at iteration 37 = 286.6883080739129
#
# Cost at iteration 38 = 286.49459213548005
#
# Cost at iteration 39 = 286.269225114622
#
# Cost at iteration 40 = 286.00424545759535
#
# Cost at iteration 41 = 285.68930813935924
#
# Cost at iteration 42 = 285.3107855730759
#
# Cost at iteration 43 = 284.8504934017646
#
# Cost at iteration 44 = 284.2839055838584
#
# Cost at iteration 45 = 283.5775132135559
#
# Cost at iteration 46 = 282.68489629177304
#
# Cost at iteration 47 = 281.5407911038923
#
# Cost at iteration 48 = 280.0519921120269
#
# Cost at iteration 49 = 278.0831941547116
#
# Cost at iteration 50 = 275.4346834984949
#
# Cost at iteration 51 = 271.8069066159348
#
# Cost at iteration 52 = 266.74430312596695
#
# Cost at iteration 53 = 259.54827399295607
#
# Cost at iteration 54 = 249.15175710094937
#
# Cost at iteration 55 = 233.97509894558522
#
# Cost at iteration 56 = 211.89771764753135
#
# Cost at iteration 57 = 180.8345984750036
#
# Cost at iteration 58 = 141.08556334258287
#
# Cost at iteration 59 = 100.0915600141566
#
# Cost at iteration 60 = 72.58023863168614
#
# Cost at iteration 61 = 63.547717656908425
#
# Cost at iteration 62 = 61.8272627828367
#
# Cost at iteration 63 = 60.877793284273
#
# Cost at iteration 64 = 59.97735941491885
#
# Cost at iteration 65 = 59.105161730715835
#
# Cost at iteration 66 = 58.25960238165675
#
# Cost at iteration 67 = 57.439516605710836
#
# Cost at iteration 68 = 56.64389891828722
#
# Cost at iteration 69 = 55.871881491377955
#
# Cost at iteration 70 = 55.12271901120726
#
# Cost at iteration 71 = 54.395775346246005
#
# Cost at iteration 72 = 53.69051151335736
#
# Cost at iteration 73 = 53.006474674027125
#
# Cost at iteration 74 = 52.34328795263237
#
# Cost at iteration 75 = 51.700640907929575
#
# Cost at iteration 76 = 51.07828052195763
#
# Cost at iteration 77 = 50.47600259970617
#
# Cost at iteration 78 = 49.8936434991886
#
# Cost at iteration 79 = 49.33107213562044
#
# Cost at iteration 80 = 48.78818222563238
#
# Cost at iteration 81 = 48.264884758048524
#
# Cost at iteration 82 = 47.76110069675905
#
# Cost at iteration 83 = 47.276753938502
#
# Cost at iteration 84 = 46.81176456370189
#
# Cost at iteration 85 = 46.366042431574854
#
# Cost at iteration 86 = 45.93948118112229
#
# Cost at iteration 87 = 45.531952707009935
#
# Cost at iteration 88 = 45.14330218330129
#
# Cost at iteration 89 = 44.77334370829581
#
# Cost at iteration 90 = 44.4218566401324
#
# Cost at iteration 91 = 44.0885826853327
#
# Cost at iteration 92 = 43.7732237912281
#
# Cost at iteration 93 = 43.47544087858798
#
# Cost at iteration 94 = 43.19485343329116
#
# Cost at iteration 95 = 42.9310399562859
#
# Cost at iteration 96 = 42.68353925024691
#
# Cost at iteration 97 = 42.45185250024204
#
# Cost at iteration 98 = 42.235446085395715
#
# Cost at iteration 99 = 42.033755039984094
#
# Cost at iteration 100 = 41.84618706653566
#
# Cost at iteration 101 = 41.67212699110331
#
# Cost at iteration 102 = 41.51094154248234
#
# Cost at iteration 103 = 41.36198433309606
#
# Cost at iteration 104 = 41.2246009196276
#
# Cost at iteration 105 = 41.09813382606301
#
# Cost at iteration 106 = 40.981927420222036
#
# Cost at iteration 107 = 40.875332546497354
#
# Cost at iteration 108 = 40.777710831673716
#
# Cost at iteration 109 = 40.6884385965507
#
# Cost at iteration 110 = 40.606910322822344
#
# Cost at iteration 111 = 40.532541641484194
#
# Cost at iteration 112 = 40.46477182523091
#
# Cost at iteration 113 = 40.40306578228038
#
# Cost at iteration 114 = 40.34691556234812
#
# Cost at iteration 115 = 40.295841396782365
#
# Cost at iteration 116 = 40.24939230397744
#
# Cost at iteration 117 = 40.207146298064636
#
# Cost at iteration 118 = 40.1687102436013
#
# Cost at iteration 119 = 40.133719401694115
#
# Cost at iteration 120 = 40.10183671392314
#
# Cost at iteration 121 = 40.07275186983862
#
# Cost at iteration 122 = 40.046142690602515
#
# Cost at iteration 123 = 40.019945405795724
#
# Cost at iteration 124 = 39.991282787280944
#
# Cost at iteration 125 = 39.96362002931876
#
# Cost at iteration 126 = 39.937832973390876
#
# Cost at iteration 127 = 39.91238317060202
#
# Cost at iteration 128 = 39.88782225982638
#
# Cost at iteration 129 = 39.86410542255085
#
# Cost at iteration 130 = 39.84072626725299
#
# Cost at iteration 131 = 39.81863314075847
#
# Cost at iteration 132 = 39.79772467231066
#
# Cost at iteration 133 = 39.777905746893495
#
# Cost at iteration 134 = 39.75908882946114
#
# Cost at iteration 135 = 39.74096898341423
#
# Cost at iteration 136 = 39.72343619594439
#
# Cost at iteration 137 = 39.706695876951514
#
# Cost at iteration 138 = 39.6906873019805
#
# Cost at iteration 139 = 39.675353756297376
#
# Cost at iteration 140 = 39.660643087477716
#
# Cost at iteration 141 = 39.646507349871236
#
# Cost at iteration 142 = 39.63290247122555
#
# Cost at iteration 143 = 39.61976657296912
#
# Cost at iteration 144 = 39.60686666611857
#
# Cost at iteration 145 = 39.59439186308412
#
# Cost at iteration 146 = 39.58231206673036
#
# Cost at iteration 147 = 39.57059847774807
#
# Cost at iteration 148 = 39.55922455330545
#
# Cost at iteration 149 = 39.5481658214712
#
# Cost at iteration 150 = 39.537399712714056
#
# Cost at iteration 151 = 39.526905404857786
#
# Cost at iteration 152 = 39.516663680563944
#
# Cost at iteration 153 = 39.506656796441675
#
# Cost at iteration 154 = 39.49686836292436
#
# Cost at iteration 155 = 39.487283234095685
#
# Cost at iteration 156 = 39.477887406692865
#
# Cost at iteration 157 = 39.46866792756087
#
# Cost at iteration 158 = 39.45961280887736
#
# Cost at iteration 159 = 39.45071095051371
#
# Cost at iteration 160 = 39.44195206894167
#
# Cost at iteration 161 = 39.43332663213808
#
# Cost at iteration 162 = 39.424825799981285
#
# Cost at iteration 163 = 39.41644136967159
#
# Cost at iteration 164 = 39.40816572574531
#
# Cost at iteration 165 = 39.39999179428664
#
# Cost at iteration 166 = 39.39191300097389
#
# Cost at iteration 167 = 39.38387667655187
#
# Cost at iteration 168 = 39.37589651552352
#
# Cost at iteration 169 = 39.367997719380256
#
# Cost at iteration 170 = 39.3601753589422
#
# Cost at iteration 171 = 39.3523805037369
#
# Cost at iteration 172 = 39.34454153012496
#
# Cost at iteration 173 = 39.33677262016945
#
# Cost at iteration 174 = 39.32906977204421
#
# Cost at iteration 175 = 39.32142909218958
#
# Cost at iteration 176 = 39.31384693176681
#
# Cost at iteration 177 = 39.30631986867247
#
# Cost at iteration 178 = 39.29884469249313
#
# Cost at iteration 179 = 39.2914183905221
#
# Cost at iteration 180 = 39.28403813477437
#
# Cost at iteration 181 = 39.27670126992186
#
# Cost at iteration 182 = 39.26940530207781
#
# Cost at iteration 183 = 39.262147888365355
#
# Cost at iteration 184 = 39.25492682721023
#
# Cost at iteration 185 = 39.24774004930287
#
# Cost at iteration 186 = 39.2405856091796
#
# Cost at iteration 187 = 39.23346167737642
#
# Cost at iteration 188 = 39.22636653311334
#
# Cost at iteration 189 = 39.2192985574698
#
# Cost at iteration 190 = 39.21225622701556
#
# Cost at iteration 191 = 39.20523810786393
#
# Cost at iteration 192 = 39.198242850116976
#
# Cost at iteration 193 = 39.191269182674716
#
# Cost at iteration 194 = 39.18431590838242
#
# Cost at iteration 195 = 39.17738189949234
#
# Cost at iteration 196 = 39.17046609341784
#
# Cost at iteration 197 = 39.16356748875967
#
# Cost at iteration 198 = 39.15668514158557
#
# Cost at iteration 199 = 39.1498181619462
#
# Cost at iteration 200 = 39.14296571061079
#
# Cost at iteration 201 = 39.136126996008386
#
# Cost at iteration 202 = 39.12930127136029
#
# Cost at iteration 203 = 39.12248783199152
#
# Cost at iteration 204 = 39.115686012809014
#
# Cost at iteration 205 = 39.108895185935964
#
# Cost at iteration 206 = 39.102114758491915
#
# Cost at iteration 207 = 39.09534417050913
#
# Cost at iteration 208 = 39.08858289297668
#
# Cost at iteration 209 = 39.08183042600375
#
# Cost at iteration 210 = 39.07508629709468
#
# Cost at iteration 211 = 39.06835005952886
#
# Cost at iteration 212 = 39.061621290838374
#
# Cost at iteration 213 = 39.05489959137781
#
# Cost at iteration 214 = 39.04818458297992
#
# Cost at iteration 215 = 39.04147590769225
#
# Cost at iteration 216 = 39.03477322658942
#
# Cost at iteration 217 = 39.028076218656416
#
# Cost at iteration 218 = 39.02138457973867
#
# Cost at iteration 219 = 39.014698021554665
#
# Cost at iteration 220 = 39.00801627076729
#
# Cost at iteration 221 = 39.00133906811043
#
# Cost at iteration 222 = 38.994666167567296
#
# Cost at iteration 223 = 38.98799733559752
#
# Cost at iteration 224 = 38.98133235040998
#
# Cost at iteration 225 = 38.97467100127855
#
# Cost at iteration 226 = 38.96801308789829
#
# Cost at iteration 227 = 38.961358419779664
#
# Cost at iteration 228 = 38.95470681567836
#
# Cost at iteration 229 = 38.94805810305872
#
# Cost at iteration 230 = 38.941412117588854
#
# Cost at iteration 231 = 38.934768702665195
#
# Cost at iteration 232 = 38.928127708965256
#
# Cost at iteration 233 = 38.92148899402646
#
# Cost at iteration 234 = 38.91485242184981
#
# Cost at iteration 235 = 38.90821786252669
#
# Cost at iteration 236 = 38.9015851918877
#
# Cost at iteration 237 = 38.89495429117192
#
# Cost at iteration 238 = 38.88832504671569
#
# Cost at iteration 239 = 38.88169734965955
#
# Cost at iteration 240 = 38.87507109567228
#
# Cost at iteration 241 = 38.868446184691315
#
# Cost at iteration 242 = 38.86182252067809
#
# Cost at iteration 243 = 38.855200011387915
#
# Cost at iteration 244 = 38.84857856815318
#
# Cost at iteration 245 = 38.84195810567936
#
# Cost at iteration 246 = 38.835338541852884
#
# Cost at iteration 247 = 38.8287197975603
#
# Cost at iteration 248 = 38.822101796517934
#
# Cost at iteration 249 = 38.81548446511168
#
# Cost at iteration 250 = 38.80886773224597
#
# Cost at iteration 251 = 38.80225152920178
#
# Cost at iteration 252 = 38.795635789502796
#
# Cost at iteration 253 = 38.789020448789515
#
# Cost at iteration 254 = 38.782405444700665
#
# Cost at iteration 255 = 38.77579071676161
#
# Cost at iteration 256 = 38.769176206279276
#
# Cost at iteration 257 = 38.762561856243195
#
# Cost at iteration 258 = 38.755947611232465
#
# Cost at iteration 259 = 38.749333417328025
#
# Cost at iteration 260 = 38.742719222030175
#
# Cost at iteration 261 = 38.736104974180904
#
# Cost at iteration 262 = 38.729490623890754
#
# Cost at iteration 263 = 38.722876122470055
#
# Cost at iteration 264 = 38.71626142236408
#
# Cost at iteration 265 = 38.7096464770921
#
# Cost at iteration 266 = 38.703031241190025
#
# Cost at iteration 267 = 38.696415670156355
#
# Cost at iteration 268 = 38.68979972040137
#
# Cost at iteration 269 = 38.683183349199275
#
# Cost at iteration 270 = 38.676566514643184
#
# Cost at iteration 271 = 38.66994917560275
#
# Cost at iteration 272 = 38.663331291684315
#
# Cost at iteration 273 = 38.65671282319333
#
# Cost at iteration 274 = 38.65009373109911
#
# Cost at iteration 275 = 38.6434739770016
#
# Cost at iteration 276 = 38.6368535231001
#
# Cost at iteration 277 = 38.630232332163885
#
# Cost at iteration 278 = 38.623610367504526
#
# Cost at iteration 279 = 38.616987592949855
#
# Cost at iteration 280 = 38.6103639728195
#
# Cost at iteration 281 = 38.60373947190186
#
# Cost at iteration 282 = 38.59711405543239
#
# Cost at iteration 283 = 38.59048768907331
#
# Cost at iteration 284 = 38.58386033889438
#
# Cost at iteration 285 = 38.57723197135489
#
# Cost at iteration 286 = 38.57060255328676
#
# Cost at iteration 287 = 38.563972051878515
#
# Cost at iteration 288 = 38.55734043466044
#
# Cost at iteration 289 = 38.550707669490365
#
# Cost at iteration 290 = 38.54407372454052
#
# Cost at iteration 291 = 38.5374368813487
#
# Cost at iteration 292 = 38.53079562828292
#
# Cost at iteration 293 = 38.5241530202637
#
# Cost at iteration 294 = 38.51750903600181
#
# Cost at iteration 295 = 38.51086364729746
#
# Cost at iteration 296 = 38.5042168263907
#
# Cost at iteration 297 = 38.49756854559032
#
# Cost at iteration 298 = 38.49091877729425
#
# Cost at iteration 299 = 38.484267493989805
#
# Cost at iteration 300 = 38.47761466825495
#
# Cost at iteration 301 = 38.47096027275936
#
# Cost at iteration 302 = 38.46430428026557
#
# Cost at iteration 303 = 38.45764666362995
#
# Cost at iteration 304 = 38.4509873958036
#
# Cost at iteration 305 = 38.444326449833426
#
# Cost at iteration 306 = 38.43766379886289
#
# Cost at iteration 307 = 38.4309994161329
#
# Cost at iteration 308 = 38.424333274982615
#
# Cost at iteration 309 = 38.41766534885018
#
# Cost at iteration 310 = 38.410995611273535
#
# Cost at iteration 311 = 38.40432403589106
#
# Cost at iteration 312 = 38.39765059644229
#
# Cost at iteration 313 = 38.39097526676858
#
# Cost at iteration 314 = 38.38429802081373
#
# Cost at iteration 315 = 38.37761883262461
#
# Cost at iteration 316 = 38.37093767635177
#
# Cost at iteration 317 = 38.36425452625
#
# Cost at iteration 318 = 38.35756935667891
#
# Cost at iteration 319 = 38.35088214210351
#
# Cost at iteration 320 = 38.34419285709469
#
# Cost at iteration 321 = 38.33750147632984
#
# Cost at iteration 322 = 38.33080797459328
#
# Cost at iteration 323 = 38.32411232677681
#
# Cost at iteration 324 = 38.31741450788025
#
# Cost at iteration 325 = 38.31071449301187
#
# Cost at iteration 326 = 38.30401225738893
#
# Cost at iteration 327 = 38.29730777633816
#
# Cost at iteration 328 = 38.2906010252962
#
# Cost at iteration 329 = 38.28389197981016
#
# Cost at iteration 330 = 38.27718061553799
#
# Cost at iteration 331 = 38.27046690824908
#
# Cost at iteration 332 = 38.26375083382462
#
# Cost at iteration 333 = 38.25703236825815
#
# Cost at iteration 334 = 38.250311487655964
#
# Cost at iteration 335 = 38.243588168237665
#
# Cost at iteration 336 = 38.236862386336576
#
# Cost at iteration 337 = 38.2301341184002
#
# Cost at iteration 338 = 38.22340334099079
#
# Cost at iteration 339 = 38.21667003078574
#
# Cost at iteration 340 = 38.20993416457809
#
# Cost at iteration 341 = 38.203195719277026
#
# Cost at iteration 342 = 38.19645467190835
#
# Cost at iteration 343 = 38.189710999614995
#
# Cost at iteration 344 = 38.1829646796575
#
# Cost at iteration 345 = 38.1762156894145
#
# Cost at iteration 346 = 38.16946400638326
#
# Cost at iteration 347 = 38.16270960818016
#
# Cost at iteration 348 = 38.15595247254124
#
# Cost at iteration 349 = 38.14919257732265
#
# Cost at iteration 350 = 38.14242990050128
#
# Cost at iteration 351 = 38.13566442017516
#
# Cost at iteration 352 = 38.128896114564135
#
# Cost at iteration 353 = 38.12212496201028
#
# Cost at iteration 354 = 38.11535094097852
#
# Cost at iteration 355 = 38.108574030057184
#
# Cost at iteration 356 = 38.101794207958505
#
# Cost at iteration 357 = 38.095011453519255
#
# Cost at iteration 358 = 38.08822574570125
#
# Cost at iteration 359 = 38.081437063592
#
# Cost at iteration 360 = 38.07464538640524
#
# Cost at iteration 361 = 38.067850693481525
#
# Cost at iteration 362 = 38.06105296428887
#
# Cost at iteration 363 = 38.05425217842328
#
# Cost at iteration 364 = 38.04744831560943
#
# Cost at iteration 365 = 38.04064135570126
#
# Cost at iteration 366 = 38.0338312786826
#
# Cost at iteration 367 = 38.02701806466777
#
# Cost at iteration 368 = 38.02020169390227
#
# Cost at iteration 369 = 38.0133821467634
#
# Cost at iteration 370 = 38.0065594037609
#
# Cost at iteration 371 = 37.99973344553766
#
# Cost at iteration 372 = 37.992904252870304
#
# Cost at iteration 373 = 37.986071806669955
#
# Cost at iteration 374 = 37.97923608798283
#
# Cost at iteration 375 = 37.97239707799098
#
# Cost at iteration 376 = 37.96555475801302
#
# Cost at iteration 377 = 37.9587091095047
#
# Cost at iteration 378 = 37.95186011405978
#
# Cost at iteration 379 = 37.945007753410586
#
# Cost at iteration 380 = 37.93815200942886
#
# Cost at iteration 381 = 37.93129286412644
#
# Cost at iteration 382 = 37.92443029965595
#
# Cost at iteration 383 = 37.91756429831165
#
# Cost at iteration 384 = 37.91069484253006
#
# Cost at iteration 385 = 37.90382191489084
#
# Cost at iteration 386 = 37.896945498117454
#
# Cost at iteration 387 = 37.89006557507798
#
# Cost at iteration 388 = 37.88318212878592
#
# Cost at iteration 389 = 37.87629514240093
#
# Cost at iteration 390 = 37.86940459922962
#
# Cost at iteration 391 = 37.86251048272638
#
# Cost at iteration 392 = 37.85561277649418
#
# Cost at iteration 393 = 37.84871146428533
#
# Cost at iteration 394 = 37.84180653000236
#
# Cost at iteration 395 = 37.8348979576988
#
# Cost at iteration 396 = 37.82798573158003
#
# Cost at iteration 397 = 37.82106983600411
#
# Cost at iteration 398 = 37.81415025548261
#
# Cost at iteration 399 = 37.80722697468148
#
# Cost at iteration 400 = 37.80029997842187
#
# Cost at iteration 401 = 37.79336925168102
#
# Cost at iteration 402 = 37.78643477959312
#
# Cost at iteration 403 = 37.77949654745019
#
# Cost at iteration 404 = 37.77255454070287
#
# Cost at iteration 405 = 37.76560874496146
#
# Cost at iteration 406 = 37.758659145996674
#
# Cost at iteration 407 = 37.75170572974057
#
# Cost at iteration 408 = 37.7447484822875
#
# Cost at iteration 409 = 37.73778738989493
#
# Cost at iteration 410 = 37.7308224389844
#
# Cost at iteration 411 = 37.72385361614244
#
# Cost at iteration 412 = 37.71688090812147
#
# Cost at iteration 413 = 37.70990430184071
#
# Cost at iteration 414 = 37.702923784387174
#
# Cost at iteration 415 = 37.695939343016505
#
# Cost at iteration 416 = 37.68895096515398
#
# Cost at iteration 417 = 37.68195863839547
#
# Cost at iteration 418 = 37.67496235050831
#
# Cost at iteration 419 = 37.667962089432315
#
# Cost at iteration 420 = 37.660957843280706
#
# Cost at iteration 421 = 37.65394960034107
#
# Cost at iteration 422 = 37.646937349076346
#
# Cost at iteration 423 = 37.63992107812574
#
# Cost at iteration 424 = 37.63290077630575
#
# Cost at iteration 425 = 37.62587643261114
#
# Cost at iteration 426 = 37.61884803621582
#
# Cost at iteration 427 = 37.611815576473994
#
# Cost at iteration 428 = 37.60477904292097
#
# Cost at iteration 429 = 37.59773842527426
#
# Cost at iteration 430 = 37.59069371343454
#
# Cost at iteration 431 = 37.58364489748662
#
# Cost at iteration 432 = 37.57659196770046
#
# Cost at iteration 433 = 37.56953473132594
#
# Cost at iteration 434 = 37.562464551959344
#
# Cost at iteration 435 = 37.5553899489267
#
# Cost at iteration 436 = 37.5483110105064
#
# Cost at iteration 437 = 37.541227724822136
#
# Cost at iteration 438 = 37.534140093965064
#
# Cost at iteration 439 = 37.527048117453916
#
# Cost at iteration 440 = 37.51995179470975
#
# Cost at iteration 441 = 37.51285112474147
#
# Cost at iteration 442 = 37.50574610623933
#
# Cost at iteration 443 = 37.49863673760461
#
# Cost at iteration 444 = 37.49152301698601
#
# Cost at iteration 445 = 37.48440494231215
#
# Cost at iteration 446 = 37.47728251132224
#
# Cost at iteration 447 = 37.47015572159454
#
# Cost at iteration 448 = 37.46302457057302
#
# Cost at iteration 449 = 37.45588905559212
#
# Cost at iteration 450 = 37.448749173899955
#
# Cost at iteration 451 = 37.44160492267992
#
# Cost at iteration 452 = 37.4344562990709
#
# Cost at iteration 453 = 37.427303300186054
#
# Cost at iteration 454 = 37.420145923130455
#
# Cost at iteration 455 = 37.41298416501753
#
# Cost at iteration 456 = 37.40581802298435
#
# Cost at iteration 457 = 37.39864749420603
#
# Cost at iteration 458 = 37.39147257590911
#
# Cost at iteration 459 = 37.38429326538409
#
# Cost at iteration 460 = 37.377109559997095
#
# Cost at iteration 461 = 37.36992145720093
#
# Cost at iteration 462 = 37.36272895454526
#
# Cost at iteration 463 = 37.3555320496862
#
# Cost at iteration 464 = 37.34833074039535
#
# Cost at iteration 465 = 37.341125024568164
#
# Cost at iteration 466 = 37.333914900231896
#
# Cost at iteration 467 = 37.32670036555291
#
# Cost at iteration 468 = 37.31948141884367
#
# Cost at iteration 469 = 37.312258058569256
#
# Cost at iteration 470 = 37.30503028335341
#
# Cost at iteration 471 = 37.29779809198434
#
# Cost at iteration 472 = 37.2905614834201
#
# Cost at iteration 473 = 37.2833204567936
#
# Cost at iteration 474 = 37.276075011417454
#
# Cost at iteration 475 = 37.268825146788444
#
# Cost at iteration 476 = 37.261570862591746
#
# Cost at iteration 477 = 37.254312158704906
#
# Cost at iteration 478 = 37.24704903520166
#
# Cost at iteration 479 = 37.23978149235541
#
# Cost at iteration 480 = 37.23250953064265
#
# Cost at iteration 481 = 37.2252331507461
#
# Cost at iteration 482 = 37.217952353557735
#
# Cost at iteration 483 = 37.210667140181585
#
# Cost at iteration 484 = 37.203377511936495
#
# Cost at iteration 485 = 37.19608347035864
#
# Cost at iteration 486 = 37.18878501720392
#
# Cost at iteration 487 = 37.18148215445036
#
# Cost at iteration 488 = 37.174174884300186
#
# Cost at iteration 489 = 37.166863209182
#
# Cost at iteration 490 = 37.159547131752696
#
# Cost at iteration 491 = 37.1522266548994
#
# Cost at iteration 492 = 37.144901781741225
#
# Cost at iteration 493 = 37.137572515631035
#
# Cost at iteration 494 = 37.13023886015704
#
# Cost at iteration 495 = 37.12290081914441
#
# Cost at iteration 496 = 37.115558396656716
#
# Cost at iteration 497 = 37.1082115969974
#
# Cost at iteration 498 = 37.10086042471114
#
# Cost at iteration 499 = 37.09350488458519
#
# Cost at iteration 500 = 37.08614498165054
#
# Cost at iteration 501 = 37.07878072118322
#
# Cost at iteration 502 = 37.07141210870543
#
# Cost at iteration 503 = 37.064039149986606
#
# Cost at iteration 504 = 37.0566618510445
#
# Cost at iteration 505 = 37.049280218146215
#
# Cost at iteration 506 = 37.04189425780916
#
# Cost at iteration 507 = 37.034503976801986
#
# Cost at iteration 508 = 37.02710938214547
#
# Cost at iteration 509 = 37.019710481113414
#
# Cost at iteration 510 = 37.0123072812334
#
# Cost at iteration 511 = 37.004899790287645
#
# Cost at iteration 512 = 36.997488016313696
#
# Cost at iteration 513 = 36.990071967605196
#
# Cost at iteration 514 = 36.98265165271254
#
# Cost at iteration 515 = 36.97522708044354
#
# Cost at iteration 516 = 36.967798259864054
#
# Cost at iteration 517 = 36.96036520029858
#
# Cost at iteration 518 = 36.95292791133083
#
# Cost at iteration 519 = 36.945486402804235
#
# Cost at iteration 520 = 36.938040684822475
#
# Cost at iteration 521 = 36.93059076774999
#
# Cost at iteration 522 = 36.923136662212364
#
# Cost at iteration 523 = 36.915678379096796
#
# Cost at iteration 524 = 36.908215929552476
#
# Cost at iteration 525 = 36.90074932499097
#
# Cost at iteration 526 = 36.893278577086534
#
# Cost at iteration 527 = 36.88580369777646
#
# Cost at iteration 528 = 36.87832469926133
#
# Cost at iteration 529 = 36.870841594005306
#
# Cost at iteration 530 = 36.863354394736334
#
# Cost at iteration 531 = 36.85586311444635
#
# Cost at iteration 532 = 36.848367766391505
#
# Cost at iteration 533 = 36.840868364092245
#
# Cost at iteration 534 = 36.83336492133348
#
# Cost at iteration 535 = 36.82585745216466
#
# Cost at iteration 536 = 36.818345970899856
#
# Cost at iteration 537 = 36.810830492117795
#
# Cost at iteration 538 = 36.80331103066186
#
# Cost at iteration 539 = 36.7957876016401
#
# Cost at iteration 540 = 36.78826022042516
#
# Cost at iteration 541 = 36.7807289026542
#
# Cost at iteration 542 = 36.773193664228856
#
# Cost at iteration 543 = 36.76565452131502
#
# Cost at iteration 544 = 36.758111490342756
#
# Cost at iteration 545 = 36.75056458800607
#
# Cost at iteration 546 = 36.743013831262715
#
# Cost at iteration 547 = 36.73545923733392
#
# Cost at iteration 548 = 36.72790082370414
#
# Cost at iteration 549 = 36.72033860812072
#
# Cost at iteration 550 = 36.71277260859359
#
# Cost at iteration 551 = 36.70520284339484
#
# Cost at iteration 552 = 36.697629331058415
#
# Cost at iteration 553 = 36.69005209037957
#
# Cost at iteration 554 = 36.682471140414506
#
# Cost at iteration 555 = 36.67488650047983
#
# Cost at iteration 556 = 36.66729819015202
#
# Cost at iteration 557 = 36.65970622926688
#
# Cost at iteration 558 = 36.65211063791898
#
# Cost at iteration 559 = 36.64451143646099
#
# Cost at iteration 560 = 36.63690864550303
#
# Cost at iteration 561 = 36.629302285912004
#
# Cost at iteration 562 = 36.62169237881088
#
# Cost at iteration 563 = 36.61407894557789
#
# Cost at iteration 564 = 36.606462007845785
#
# Cost at iteration 565 = 36.598841587501006
#
# Cost at iteration 566 = 36.59121770668282
#
# Cost at iteration 567 = 36.583590387782394
#
# Cost at iteration 568 = 36.57595965344193
#
# Cost at iteration 569 = 36.568325526553664
#
# Cost at iteration 570 = 36.560688030258866
#
# Cost at iteration 571 = 36.55304718794684
#
# Cost at iteration 572 = 36.545403023253805
#
# Cost at iteration 573 = 36.53775556006184
#
# Cost at iteration 574 = 36.530104822497705
#
# Cost at iteration 575 = 36.52245083493169
#
# Cost at iteration 576 = 36.5147936219764
#
# Cost at iteration 577 = 36.5071332084855
#
# Cost at iteration 578 = 36.49946961955239
#
# Cost at iteration 579 = 36.491802880508985
#
# Cost at iteration 580 = 36.484133016924226
#
# Cost at iteration 581 = 36.47646005460277
#
# Cost at iteration 582 = 36.468784019583545
#
# Cost at iteration 583 = 36.46110493813823
#
# Cost at iteration 584 = 36.45342283676979
#
# Cost at iteration 585 = 36.445737742210916
#
# Cost at iteration 586 = 36.43804968142243
#
# Cost at iteration 587 = 36.43035868159166
#
# Cost at iteration 588 = 36.422664770130815
#
# Cost at iteration 589 = 36.4149679746752
#
# Cost at iteration 590 = 36.40726832308158
#
# Cost at iteration 591 = 36.399565843426295
#
# Cost at iteration 592 = 36.39186056400354
#
# Cost at iteration 593 = 36.38415251332346
#
# Cost at iteration 594 = 36.376441720110265
#
# Cost at iteration 595 = 36.36872821330029
#
# Cost at iteration 596 = 36.36101202204002
#
# Cost at iteration 597 = 36.353293175684115
#
# Cost at iteration 598 = 36.345571703793325
#
# Cost at iteration 599 = 36.3378476361324
#
# Cost at iteration 600 = 36.33012100266799
#
# Cost at iteration 601 = 36.32239183356646
#
# Cost at iteration 602 = 36.314660159191696
#
# Cost at iteration 603 = 36.30692601010284
#
# Cost at iteration 604 = 36.299189417052034
#
# Cost at iteration 605 = 36.291450410982094
#
# Cost at iteration 606 = 36.28370902302413
#
# Cost at iteration 607 = 36.27596528449518
#
# Cost at iteration 608 = 36.26821922689574
#
# Cost at iteration 609 = 36.260470881907295
#
# Cost at iteration 610 = 36.25272028138984
#
# Cost at iteration 611 = 36.24496745737929
#
# Cost at iteration 612 = 36.23721244208489
#
# Cost at iteration 613 = 36.22945526788661
#
# Cost at iteration 614 = 36.221695967332465
#
# Cost at iteration 615 = 36.21393457313582
#
# Cost at iteration 616 = 36.20617111817262
#
# Cost at iteration 617 = 36.19840563547865
#
# Cost at iteration 618 = 36.1906381582467
#
# Cost at iteration 619 = 36.1828687198237
#
# Cost at iteration 620 = 36.17509735370786
#
# Cost at iteration 621 = 36.16732409354571
#
# Cost at iteration 622 = 36.15954897312916
#
# Cost at iteration 623 = 36.15177202639249
#
# Cost at iteration 624 = 36.14399328740933
#
# Cost at iteration 625 = 36.13621279038957
#
# Cost at iteration 626 = 36.12843056967625
#
# Cost at iteration 627 = 36.120646659742434
#
# Cost at iteration 628 = 36.112861095188045
#
# Cost at iteration 629 = 36.10507391073662
#
# Cost at iteration 630 = 36.09728514123212
#
# Cost at iteration 631 = 36.08949482163556
#
# Cost at iteration 632 = 36.081702987021814
#
# Cost at iteration 633 = 36.07390967257615
#
# Cost at iteration 634 = 36.06611491359097
#
# Cost at iteration 635 = 36.0583187454623
#
# Cost at iteration 636 = 36.05052120368641
#
# Cost at iteration 637 = 36.0427223238563
#
# Cost at iteration 638 = 36.03492214165825
#
# Cost at iteration 639 = 36.02712069286822
#
# Cost at iteration 640 = 36.019318013348325
#
# Cost at iteration 641 = 36.01151413904323
#
# Cost at iteration 642 = 36.00370910597652
#
# Cost at iteration 643 = 35.99590295024706
#
# Cost at iteration 644 = 35.98809570802528
#
# Cost at iteration 645 = 35.98028741554952
#
# Cost at iteration 646 = 35.97247810912224
#
# Cost at iteration 647 = 35.964667825106275
#
# Cost at iteration 648 = 35.95685659992108
#
# Cost at iteration 649 = 35.94904447003882
#
# Cost at iteration 650 = 35.94123147198064
#
# Cost at iteration 651 = 35.933417642312726
#
# Cost at iteration 652 = 35.92560301764243
#
# Cost at iteration 653 = 35.917787634614385
#
# Cost at iteration 654 = 35.90997152990652
#
# Cost at iteration 655 = 35.90215474022614
#
# Cost at iteration 656 = 35.89433730230592
#
# Cost at iteration 657 = 35.88651925289994
#
# Cost at iteration 658 = 35.878700628779605
#
# Cost at iteration 659 = 35.870881466729664
#
# Cost at iteration 660 = 35.86306180354411
#
# Cost at iteration 661 = 35.8552416760221
#
# Cost at iteration 662 = 35.84742112096391
#
# Cost at iteration 663 = 35.83960017516672
#
# Cost at iteration 664 = 35.83177887542059
#
# Cost at iteration 665 = 35.823957258504265
#
# Cost at iteration 666 = 35.81613536118099
#
# Cost at iteration 667 = 35.808313220194385
#
# Cost at iteration 668 = 35.80049087226424
#
# Cost at iteration 669 = 35.792668354082295
#
# Cost at iteration 670 = 35.78484570230803
#
# Cost at iteration 671 = 35.77702295356446
#
# Cost at iteration 672 = 35.769200144433896
#
# Cost at iteration 673 = 35.761377311453664
#
# Cost at iteration 674 = 35.75355449111192
#
# Cost at iteration 675 = 35.74573171984333
#
# Cost at iteration 676 = 35.7379090340248
#
# Cost at iteration 677 = 35.730086469971255
#
# Cost at iteration 678 = 35.72226406393132
#
# Cost at iteration 679 = 35.71444185208302
#
# Cost at iteration 680 = 35.70661987052949
#
# Cost at iteration 681 = 35.698798155294746
#
# Cost at iteration 682 = 35.69097674231931
#
# Cost at iteration 683 = 35.68315566745594
#
# Cost at iteration 684 = 35.67533496646536
#
# Cost at iteration 685 = 35.66751467501191
#
# Cost at iteration 686 = 35.65969482865928
#
# Cost at iteration 687 = 35.65187546286625
#
# Cost at iteration 688 = 35.644056612982304
#
# Cost at iteration 689 = 35.63623831424343
#
# Cost at iteration 690 = 35.628420601767765
#
# Cost at iteration 691 = 35.620603510551405
#
# Cost at iteration 692 = 35.61278707546402
#
# Cost at iteration 693 = 35.604971331244684
#
# Cost at iteration 694 = 35.597156312497546
#
# Cost at iteration 695 = 35.58934205368763
#
# Cost at iteration 696 = 35.58152858913658
#
# Cost at iteration 697 = 35.573715953018414
#
# Cost at iteration 698 = 35.5659041793553
#
# Cost at iteration 699 = 35.55809330201339
#
# Cost at iteration 700 = 35.55028335469861
#
# Cost at iteration 701 = 35.54247437095243
#
# Cost at iteration 702 = 35.53466638414778
#
# Cost at iteration 703 = 35.52685942748487
#
# Cost at iteration 704 = 35.51905353398702
#
# Cost at iteration 705 = 35.51124873649659
#
# Cost at iteration 706 = 35.503445067670874
#
# Cost at iteration 707 = 35.495642559978016
#
# Cost at iteration 708 = 35.487841245692955
#
# Cost at iteration 709 = 35.48004115689337
#
# Cost at iteration 710 = 35.47224232545573
#
# Cost at iteration 711 = 35.46444478305121
#
# Cost at iteration 712 = 35.4566485611418
#
# Cost at iteration 713 = 35.4488536909763
#
# Cost at iteration 714 = 35.441060203586446
#
# Cost at iteration 715 = 35.433268129783
#
# Cost at iteration 716 = 35.425477500151885
#
# Cost at iteration 717 = 35.41768834505035
#
# Cost at iteration 718 = 35.409900694603145
#
# Cost at iteration 719 = 35.402114578698736
#
# Cost at iteration 720 = 35.39433002698559
#
# Cost at iteration 721 = 35.386547068868445
#
# Cost at iteration 722 = 35.378765733504565
#
# Cost at iteration 723 = 35.37098604980015
#
# Cost at iteration 724 = 35.36320804640671
#
# Cost at iteration 725 = 35.355431751717404
#
# Cost at iteration 726 = 35.34765719386359
#
# Cost at iteration 727 = 35.33988440071121
#
# Cost at iteration 728 = 35.332113399857384
#
# Cost at iteration 729 = 35.32434421862691
#
# Cost at iteration 730 = 35.31657688406887
#
# Cost at iteration 731 = 35.30881142295329
#
# Cost at iteration 732 = 35.301047861767756
#
# Cost at iteration 733 = 35.29328622671416
#
# Cost at iteration 734 = 35.28552654370544
#
# Cost at iteration 735 = 35.27776883836236
#
# Cost at iteration 736 = 35.27001313601037
#
# Cost at iteration 737 = 35.26225946167644
#
# Cost at iteration 738 = 35.25450784008601
#
# Cost at iteration 739 = 35.246758295659916
#
# Cost at iteration 740 = 35.239010852511456
#
# Cost at iteration 741 = 35.231265534443345
#
# Cost at iteration 742 = 35.223522364944905
#
# Cost at iteration 743 = 35.21578136718916
#
# Cost at iteration 744 = 35.20804256402999
#
# Cost at iteration 745 = 35.200305977999456
#
# Cost at iteration 746 = 35.192571631304965
#
# Cost at iteration 747 = 35.18483954582671
#
# Cost at iteration 748 = 35.177109743115004
#
# Cost at iteration 749 = 35.169382244387634
#
# Cost at iteration 750 = 35.16165707052747
#
# Cost at iteration 751 = 35.15393424207991
#
# Cost at iteration 752 = 35.14621377925045
#
# Cost at iteration 753 = 35.13849570190235
#
# Cost at iteration 754 = 35.130780029554295
#
# Cost at iteration 755 = 35.12306678137809
#
# Cost at iteration 756 = 35.11535597619654
#
# Cost at iteration 757 = 35.107647632481154
#
# Cost at iteration 758 = 35.09994176835012
#
# Cost at iteration 759 = 35.092238401566235
#
# Cost at iteration 760 = 35.08453754953484
#
# Cost at iteration 761 = 35.07683922930195
#
# Cost at iteration 762 = 35.06914345755229
#
# Cost at iteration 763 = 35.06145025060745
#
# Cost at iteration 764 = 35.053759624424146
#
# Cost at iteration 765 = 35.04607159459241
#
# Cost at iteration 766 = 35.03838617633397
#
# Cost at iteration 767 = 35.03070338450057
#
# Cost at iteration 768 = 35.02302323357244
#
# Cost at iteration 769 = 35.01534573765674
#
# Cost at iteration 770 = 35.00767091048614
#
# Cost at iteration 771 = 34.999998765417324
#
# Cost at iteration 772 = 34.99232931542977
#
# Cost at iteration 773 = 34.984662573124346
#
# Cost at iteration 774 = 34.9769985507221
#
# Cost at iteration 775 = 34.96933726006309
#
# Cost at iteration 776 = 34.961678712605234
#
# Cost at iteration 777 = 34.95402291942325
#
# Cost at iteration 778 = 34.94636989120763
#
# Cost at iteration 779 = 34.93871963826367
#
# Cost at iteration 780 = 34.931072170510575
#
# Cost at iteration 781 = 34.92342749748061
#
# Cost at iteration 782 = 34.91578562831829
#
# Cost at iteration 783 = 34.908146571779646
#
# Cost at iteration 784 = 34.900510336231555
#
# Cost at iteration 785 = 34.89287692965107
#
# Cost at iteration 786 = 34.88524635962487
#
# Cost at iteration 787 = 34.87761863334877
#
# Cost at iteration 788 = 34.86999375762719
#
# Cost at iteration 789 = 34.862371738872824
#
# Cost at iteration 790 = 34.85475258310618
#
# Cost at iteration 791 = 34.847136295955394
#
# Cost at iteration 792 = 34.83952288265588
#
# Cost at iteration 793 = 34.8319123480502
#
# Cost at iteration 794 = 34.824304696587916
#
# Cost at iteration 795 = 34.81669993232547
#
# Cost at iteration 796 = 34.80909805892617
#
# Cost at iteration 797 = 34.8014990796602
#
# Cost at iteration 798 = 34.79390299740472
#
# Cost at iteration 799 = 34.786309814643936
#
# Cost at iteration 800 = 34.77871953346929
#
# Cost at iteration 801 = 34.77113215557974
#
# Cost at iteration 802 = 34.763547682281946
#
# Cost at iteration 803 = 34.75596611449065
#
# Cost at iteration 804 = 34.74838745272903
#
# Cost at iteration 805 = 34.74081169712913
#
# Cost at iteration 806 = 34.733238847432375
#
# Cost at iteration 807 = 34.72566890299
#
# Cost at iteration 808 = 34.718101862763724
#
# Cost at iteration 809 = 34.710537725326276
#
# Cost at iteration 810 = 34.702976488862156
#
# Cost at iteration 811 = 34.69541815116824
#
# Cost at iteration 812 = 34.687862709654645
#
# Cost at iteration 813 = 34.68031016134547
#
# Cost at iteration 814 = 34.672760502879626
#
# Cost at iteration 815 = 34.665213730511816
#
# Cost at iteration 816 = 34.657669840113385
#
# Cost at iteration 817 = 34.65012882717337
#
# Cost at iteration 818 = 34.64259068679945
#
# Cost at iteration 819 = 34.635055413719115
#
# Cost at iteration 820 = 34.62752300228066
#
# Cost at iteration 821 = 34.619993446454465
#
# Cost at iteration 822 = 34.61246673983402
#
# Cost at iteration 823 = 34.604942875637356
#
# Cost at iteration 824 = 34.59742184670812
#
# Cost at iteration 825 = 34.58990364551706
#
# Cost at iteration 826 = 34.582388264163214
#
# Cost at iteration 827 = 34.574875694375436
#
# Cost at iteration 828 = 34.56736592751369
#
# Cost at iteration 829 = 34.55985895457065
#
# Cost at iteration 830 = 34.55235476617303
#
# Cost at iteration 831 = 34.544853352583274
#
# Cost at iteration 832 = 34.537354703701
#
# Cost at iteration 833 = 34.52985880906466
#
# Cost at iteration 834 = 34.52236565785313
#
# Cost at iteration 835 = 34.514875238887434
#
# Cost at iteration 836 = 34.507387540632344
#
# Cost at iteration 837 = 34.49990255119822
#
# Cost at iteration 838 = 34.492420258342634
#
# Cost at iteration 839 = 34.484940649472286
#
# Cost at iteration 840 = 34.477463711644695
#
# Cost at iteration 841 = 34.46998943157015
#
# Cost at iteration 842 = 34.46251779561346
#
# Cost at iteration 843 = 34.45504878979602
#
# Cost at iteration 844 = 34.44758239979747
#
# Cost at iteration 845 = 34.44011861095799
#
# Cost at iteration 846 = 34.43265740827986
#
# Cost at iteration 847 = 34.425198776429916
#
# Cost at iteration 848 = 34.41774269974104
#
# Cost at iteration 849 = 34.41028916221481
#
# Cost at iteration 850 = 34.40283814752286
#
# Cost at iteration 851 = 34.39538963900975
#
# Cost at iteration 852 = 34.3879436196942
#
# Cost at iteration 853 = 34.380500072272184
#
# Cost at iteration 854 = 34.37305897911795
#
# Cost at iteration 855 = 34.36562032228749
#
# Cost at iteration 856 = 34.358161188084935
#
# Cost at iteration 857 = 34.3506834717251
#
# Cost at iteration 858 = 34.34320748495312
#
# Cost at iteration 859 = 34.33573296908559
#
# Cost at iteration 860 = 34.32826045202528
#
# Cost at iteration 861 = 34.32078948171881
#
# Cost at iteration 862 = 34.31332074968865
#
# Cost at iteration 863 = 34.30585354059818
#
# Cost at iteration 864 = 34.29838881613105
#
# Cost at iteration 865 = 34.2909254812011
#
# Cost at iteration 866 = 34.283464927961525
#
# Cost at iteration 867 = 34.27600549231649
#
# Cost at iteration 868 = 34.26854924609478
#
# Cost at iteration 869 = 34.26109365002049
#
# Cost at iteration 870 = 34.25364185178394
#
# Cost at iteration 871 = 34.2461899394056
#
# Cost at iteration 872 = 34.238742777181436
#
# Cost at iteration 873 = 34.23129426494414
#
# Cost at iteration 874 = 34.223852035052005
#
# Cost at iteration 875 = 34.21640644826252
#
# Cost at iteration 876 = 34.20896965359325
#
# Cost at iteration 877 = 34.20152405398636
#
# Cost at iteration 878 = 34.19408640791896
#
# Cost at iteration 879 = 34.18663694942653
#
# Cost at iteration 880 = 34.17920664419555
#
# Cost at iteration 881 = 34.17175564408848
#
# Cost at iteration 882 = 34.16433549181646
#
# Cost at iteration 883 = 34.15687934152432
#
# Cost at iteration 884 = 34.14947420857623
#
# Cost at iteration 885 = 34.1420064337361
#
# Cost at iteration 886 = 34.13462496838869
#
# Cost at iteration 887 = 34.12713390858738
#
# Cost at iteration 888 = 34.11979174915613
#
# Cost at iteration 889 = 34.112246580345655
#
# Cost at iteration 890 = 34.10489542336923
#
# Cost at iteration 891 = 34.09723892376084
#
# Cost at iteration 892 = 34.089994518409895
#
# Cost at iteration 893 = 34.082198031948735
#
# Cost at iteration 894 = 34.07515086655634
#
# Cost at iteration 895 = 34.067092250434804
#
# Cost at iteration 896 = 34.06041528311447
#
# Cost at iteration 897 = 34.05186141795656
#
# Cost at iteration 898 = 34.04589162728493
#
# Cost at iteration 899 = 34.036395691909476
#
# Cost at iteration 900 = 34.03180437975133
#
# Cost at iteration 901 = 34.020511951055404
#
# Cost at iteration 902 = 34.018677236446514
#
# Cost at iteration 903 = 34.00389842909181
#
# Cost at iteration 904 = 34.007855927248116
#
# Cost at iteration 905 = 33.98637628550904
#
# Cost at iteration 906 = 34.00327096782969
#
# Cost at iteration 907 = 33.96992224390236
#
# Cost at iteration 908 = 34.01641830547161
#
# Cost at iteration 909 = 33.96777983932938
#
# Cost at iteration 910 = 34.09527952377778
#
# Cost at iteration 911 = 34.054746582112664
#
# Cost at iteration 912 = 34.407758054742054
#
# Cost at iteration 913 = 34.58539728163648
#
# Cost at iteration 914 = 35.7193571304244
#
# Cost at iteration 915 = 37.160731411781676
#
# Cost at iteration 916 = 41.275956956158595
#
# Cost at iteration 917 = 48.69797944481848
#
# Cost at iteration 918 = 61.33528780346253
#
# Cost at iteration 919 = 87.67290774139084
#
# Cost at iteration 920 = 94.7242749813177
#
# Cost at iteration 921 = 125.41077210318291
#
# Cost at iteration 922 = 67.7180099594625
#
# Cost at iteration 923 = 64.23928282769907
#
# Cost at iteration 924 = 43.152900600166326
#
# Cost at iteration 925 = 40.19291300648031
#
# Cost at iteration 926 = 36.90991896598191
#
# Cost at iteration 927 = 35.989586479726896
#
# Cost at iteration 928 = 35.30528188961428
#
# Cost at iteration 929 = 35.02521138340707
#
# Cost at iteration 930 = 34.84209211978942
#
# Cost at iteration 931 = 34.74387947464803
#
# Cost at iteration 932 = 34.68143029804988
#
# Cost at iteration 933 = 34.63730127574387
#
# Cost at iteration 934 = 34.60995171725801
#
# Cost at iteration 935 = 34.584474600423
#
# Cost at iteration 936 = 34.568093571652085
#
# Cost at iteration 937 = 34.55123106684688
#
# Cost at iteration 938 = 34.539123050194874
#
# Cost at iteration 939 = 34.52602289285395
#
# Cost at iteration 940 = 34.516001470845566
#
# Cost at iteration 941 = 34.50258667627151
#
# Cost at iteration 942 = 34.49384735415876
#
# Cost at iteration 943 = 34.480862319677854
#
# Cost at iteration 944 = 34.47221922960434
#
# Cost at iteration 945 = 34.46083290449886
#
# Cost at iteration 946 = 34.45228120641438
#
# Cost at iteration 947 = 34.441923186416844
#
# Cost at iteration 948 = 34.433458133859666
#
# Cost at iteration 949 = 34.42378047243539
#
# Cost at iteration 950 = 34.41539419630255
#
# Cost at iteration 951 = 34.40611491259888
#
# Cost at iteration 952 = 34.397796212709956
#
# Cost at iteration 953 = 34.388807506002834
#
# Cost at iteration 954 = 34.38054958774478
#
# Cost at iteration 955 = 34.371817681564956
#
# Cost at iteration 956 = 34.363613262013125
#
# Cost at iteration 957 = 34.35506701988915
#
# Cost at iteration 958 = 34.34690875540239
#
# Cost at iteration 959 = 34.33849925628496
#
# Cost at iteration 960 = 34.3303804982391
#
# Cost at iteration 961 = 34.322073606606764
#
# Cost at iteration 962 = 34.313988684161735
#
# Cost at iteration 963 = 34.305760283003956
#
# Cost at iteration 964 = 34.29770454071556
#
# Cost at iteration 965 = 34.289537409584035
#
# Cost at iteration 966 = 34.281507127864685
#
# Cost at iteration 967 = 34.2733888593781
#
# Cost at iteration 968 = 34.265381127793304
#
# Cost at iteration 969 = 34.25730271314829
#
# Cost at iteration 970 = 34.249315293425724
#
# Cost at iteration 971 = 34.241270147255186
#
# Cost at iteration 972 = 34.233301344232245
#
# Cost at iteration 973 = 34.22528462319545
#
# Cost at iteration 974 = 34.217333171598376
#
# Cost at iteration 975 = 34.209341292588654
#
# Cost at iteration 976 = 34.2014062619745
#
# Cost at iteration 977 = 34.193436557985
#
# Cost at iteration 978 = 34.185517275337155
#
# Cost at iteration 979 = 34.17756774747532
#
# Cost at iteration 980 = 34.1696490353642
#
# Cost at iteration 981 = 34.161700872170506
#
# Cost at iteration 982 = 34.15378989605918
#
# Cost at iteration 983 = 34.14585844023306
#
# Cost at iteration 984 = 34.137961902774244
#
# Cost at iteration 985 = 34.130046480556345
#
# Cost at iteration 986 = 34.12216434576184
#
# Cost at iteration 987 = 34.11426441730744
#
# Cost at iteration 988 = 34.10639668521761
#
# Cost at iteration 989 = 34.09851180401683
#
# Cost at iteration 990 = 34.09065850371218
#
# Cost at iteration 991 = 34.08278828535995
#
# Cost at iteration 992 = 34.07494947130816
#
# Cost at iteration 993 = 34.06709356871367
#
# Cost at iteration 994 = 34.05926932011783
#
# Cost at iteration 995 = 34.05142740289475
#
# Cost at iteration 996 = 34.04361782593199
#
# Cost at iteration 997 = 34.03578956211983
#
# Cost at iteration 998 = 34.02799479520577
#
# Cost at iteration 999 = 34.02017983368496
#
# Cost at iteration 1000 = 34.012400056187275
#
# Root Mean Squared Error on Training Data = 8.246768822779648
# Root Mean Squared Error on Test Data = 8.43916336208915
