# %% [markdown]
# # DS : CHE

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# **Welcome to your first assignment of SimuTech Winter Project 2022! I hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about properties of superheated vapor.**
#
# The dataset consists of the thermophysical properties: specific volume, specific internal energy, specific enthalpy, specific entropy of superheated vapor.
#
# Pressure is in kPa and Temperature in centigrade. In the dataframe 75, 100, 125 are temperatures.
#
# **There are some interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas and matplotlib!***

# %% [markdown]
# ### 1) Import all the libraries

# %%
#your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file.

# %%
#your code here
df=pd.read_csv("superheated_vapor_properties.csv")

# %% [markdown]
# ### 3) Display shape of dataframe

# %%
#your code here
print('Data Frame Shape: ', df.shape)
# Out:
# Data Frame Shape:  (544, 37)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
print(df.columns.tolist())
# Out:
# ['Pressure', 'Property', 'Liq_Sat', 'Vap_Sat', '75', '100', '125', '150', '175', '200', '220', '225', '240', '250', '260', '275', '280', '290', '300', '320', '325', '340', '350', '360', '375', '380', '400', '425', '450', '475', '500', '525', '550', '575', '600', '625', '650']

# %% [markdown]
# ### 5) Display the number of null values in each column of the dataframe

# %%
#your code here
df.isna().sum()
# Out:
# Pressure      0
# Property      0
# Liq_Sat       0
# Vap_Sat       0
# 75          528
# 100         508
# 125         488
# 150         448
# 175         384
# 200         320
# 220         408
# 225         400
# 240         408
# 250         344
# 260         384
# 275         340
# 280         380
# 290         488
# 300          60
# 320         480
# 325         136
# 340         476
# 350          68
# 360         476
# 375         204
# 380         476
# 400           0
# 425         204
# 450           0
# 475         204
# 500           0
# 525         272
# 550           0
# 575         340
# 600           0
# 625         476
# 650           0
# dtype: int64

# %% [markdown]
# ###  6) Print a list of all the unique items in the Property column

# %%
#your code here
print(df.Property.unique())
# Out:
# ['V' 'U' 'H' 'S']

# %% [markdown]
# ### 7) Create a column which contains the Pressure and Property columns, seperated with 'at' (For eg. V at 1, H at 101.325). Using this print the following:
# - Enthalpy at 75 kPa and 573 K
# - Entropy at 493 K and 250 kPa

# %%
#your code here
df1 = df["Property"].astype(str) + " "+ "at"+ " "+ df["Pressure"].astype(str)
df["Property at pressure"] = df1
col_new1 = df[df["Property at pressure"]=='H at 75.0']
col_new2 = df[df["Property at pressure"]=='H at 75.0']
print(col_new1["300"])
print(col_new2["220"])
# Out:
# 26    3075.1
# Name: 300, dtype: float64
# 26   NaN
# Name: 220, dtype: float64

# %% [markdown]
# ### 8) Find out the column with the highest number of missing values

# %%
#your code here
df.count().idxmin()
# Out:
# '75'

# %% [markdown]
# ### 9) What is the average enthalpy of Sat. Liq. at all different pressures in the dataset ?

# %%
#your code here
df.loc[df['Property']=="H","Average"] = df['Liq_Sat']
ans=df["Average"].mean()
print(ans)
# Out:
# 936.9707720588236

# %% [markdown]
# ### 10) Separate out the V,U,H,S data from the dataset into V_data, U_data, H_data, S_data

# %%
#your code here
V_data = pd.DataFrame()
U_data = pd.DataFrame()
H_data = pd.DataFrame()
S_data = pd.DataFrame()

for i in range(len(df.index)):
    if df['Property'].values[i] == "V":
        V_data = V_data.append(df.loc[i], ignore_index=True)
    if df['Property'].values[i] == "U":
        U_data = U_data.append(df.loc[i], ignore_index=True)
    if df['Property'].values[i] == "H":
        H_data = H_data.append(df.loc[i], ignore_index=True)
    if df['Property'].values[i] == "S":
        S_data = S_data.append(df.loc[i], ignore_index=True)

print(V_data)
print(U_data)
print(H_data)
print(S_data)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# ...
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
#      Pressure Property  Liq_Sat     Vap_Sat        75       100       125  \
# 0         1.0        V    1.000  129200.000  160640.0  172180.0  183720.0
# 1        10.0        V    1.010   14670.000   16030.0   17190.0   18350.0
# 2        20.0        V    1.017    7649.800    8000.0    8584.7    9167.1
# 3        30.0        V    1.022    5229.300    5322.0    5714.4    6104.6
# 4        40.0        V    1.027    3993.400       NaN    4279.2    4573.3
# ..        ...      ...      ...         ...       ...       ...       ...
# 131   10600.0        V    1.474      16.778       NaN       NaN       NaN
# 132   10800.0        V    1.481      16.385       NaN       NaN       NaN
# 133   11000.0        V    1.489      16.006       NaN       NaN       NaN
# 134   11200.0        V    1.496      15.639       NaN       NaN       NaN
# 135   11400.0        V    1.504      15.284       NaN       NaN       NaN
#
#           150       175       200  ...     475         500     525  \
# 0    195270.0  206810.0  218350.0  ...     NaN  356810.000     NaN
# 1     19510.0   20660.0   21820.0  ...     NaN   35670.000     NaN
# 2      9748.0   10320.0   10900.0  ...     NaN   17830.000     NaN
# 3      6493.2    6880.8    7267.5  ...     NaN   11890.000     NaN
# 4      4865.8    5157.2    5447.8  ...     NaN    8917.600     NaN
# ..        ...       ...       ...  ...     ...         ...     ...
# 131       NaN       NaN       NaN  ...  29.313      30.732  32.106
# 132       NaN       NaN       NaN  ...  28.706      30.106  31.461
# 133       NaN       NaN       NaN  ...  28.120      29.503  30.839
# 134       NaN       NaN       NaN  ...  27.555      28.921  30.240
# 135       NaN       NaN       NaN  ...  27.010      28.359  29.661
#
#             550     575         600     625         650  Property at pressure  \
# 0    379880.000     NaN  402960.000     NaN  426040.000              V at 1.0
# 1     37980.000     NaN   40290.000     NaN   42600.000             V at 10.0
# 2     18990.000     NaN   20140.000     NaN   21300.000             V at 20.0
# 3     12660.000     NaN   13430.000     NaN   14190.000             V at 30.0
# 4      9494.900     NaN   10070.000     NaN   10640.000             V at 40.0
# ..          ...     ...         ...     ...         ...                   ...
# 131      33.444  34.753      36.039  37.304      38.552          V at 10600.0
# 132      32.779  34.069      35.335  36.580      37.808          V at 10800.0
# 133      32.139  33.410      34.656  35.882      37.091          V at 11000.0
# 134      31.521  32.774      34.002  35.210      36.400          V at 11200.0
# 135      30.925  32.160      33.370  34.560      35.733          V at 11400.0
#
#      Average
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 131      NaN
# 132      NaN
# 133      NaN
# 134      NaN
# 135      NaN
#
# [136 rows x 39 columns]
#      Pressure Property   Liq_Sat  Vap_Sat      75     100     125     150  \
# 0         1.0        U    29.334   2385.2  2480.8  2516.4  2552.3  2588.5
# 1        10.0        U   191.822   2438.0  2479.7  2515.6  2551.6  2588.0
# 2        20.0        U   251.432   2456.9  2478.4  2514.6  2550.9  2587.4
# 3        30.0        U   289.271   2468.6  2477.1  2513.6  2550.2  2586.8
# 4        40.0        U   317.609   2477.1     NaN  2512.6  2549.4  2586.2
# ..        ...      ...       ...      ...     ...     ...     ...     ...
# 131   10600.0        U  1418.100   2539.0     NaN     NaN     NaN     NaN
# 132   10800.0        U  1426.200   2536.2     NaN     NaN     NaN     NaN
# 133   11000.0        U  1434.200   2533.2     NaN     NaN     NaN     NaN
# 134   11200.0        U  1442.100   2530.3     NaN     NaN     NaN     NaN
# 135   11400.0        U  1450.000   2527.2     NaN     NaN     NaN     NaN
#
#         175     200  ...     475     500     525     550     575     600  \
# 0    2624.9  2661.7  ...     NaN  3132.4     NaN  3216.7     NaN  3302.6
# 1    2624.5  2661.4  ...     NaN  3132.3     NaN  3216.6     NaN  3302.6
# 2    2624.1  2661.0  ...     NaN  3132.3     NaN  3216.5     NaN  3302.5
# 3    2623.6  2660.7  ...     NaN  3132.2     NaN  3216.5     NaN  3302.5
# 4    2623.2  2660.3  ...     NaN  3132.1     NaN  3216.4     NaN  3302.4
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 131     NaN     NaN  ...  2991.1  3041.4  3090.7  3139.3  3187.5  3235.6
# 132     NaN     NaN  ...  2989.0  3039.6  3089.0  3137.8  3186.1  3234.3
# 133     NaN     NaN  ...  2986.9  3037.7  3087.3  3136.2  3184.7  3233.0
# 134     NaN     NaN  ...  2984.8  3035.8  3085.6  3134.7  3183.3  3231.7
# 135     NaN     NaN  ...  2982.6  3033.9  3083.9  3133.1  3181.9  3230.4
#
#         625     650  Property at pressure  Average
# 0       NaN  3390.3              U at 1.0      NaN
# 1       NaN  3390.3             U at 10.0      NaN
# 2       NaN  3390.2             U at 20.0      NaN
# 3       NaN  3390.2             U at 30.0      NaN
# 4       NaN  3390.1             U at 40.0      NaN
# ..      ...     ...                   ...      ...
# 131  3283.6  3331.7          U at 10600.0      NaN
# 132  3282.4  3330.6          U at 10800.0      NaN
# 133  3281.2  3329.5          U at 11000.0      NaN
# 134  3280.0  3328.4          U at 11200.0      NaN
# 135  3278.8  3327.2          U at 11400.0      NaN
#
# [136 rows x 39 columns]
#      Pressure Property   Liq_Sat  Vap_Sat      75     100     125     150  \
# 0         1.0        H    29.335   2514.4  2641.5  2688.6  2736.0  2783.7
# 1        10.0        H   191.832   2584.8  2640.0  2687.5  2735.2  2783.1
# 2        20.0        H   251.453   2609.9  2638.4  2686.3  2734.2  2782.3
# 3        30.0        H   289.302   2625.4  2636.8  2685.1  2733.3  2781.6
# 4        40.0        H   317.650   2636.9     NaN  2683.8  2732.3  2780.9
# ..        ...      ...       ...      ...     ...     ...     ...     ...
# 131   10600.0        H  1433.700   2716.9     NaN     NaN     NaN     NaN
# 132   10800.0        H  1442.200   2713.1     NaN     NaN     NaN     NaN
# 133   11000.0        H  1450.600   2709.3     NaN     NaN     NaN     NaN
# 134   11200.0        H  1458.900   2705.4     NaN     NaN     NaN     NaN
# 135   11400.0        H  1467.200   2701.5     NaN     NaN     NaN     NaN
#
#         175     200  ...     475     500     525     550     575     600  \
# 0    2831.7  2880.1  ...     NaN  3489.2     NaN  3596.5     NaN  3705.6
# 1    2831.2  2879.6  ...     NaN  3489.1     NaN  3596.5     NaN  3705.5
# 2    2830.6  2879.2  ...     NaN  3489.0     NaN  3596.4     NaN  3705.4
# 3    2830.0  2878.7  ...     NaN  3488.9     NaN  3596.3     NaN  3705.4
# 4    2829.5  2878.2  ...     NaN  3488.8     NaN  3596.2     NaN  3705.3
# ..      ...     ...  ...     ...     ...     ...     ...     ...     ...
# 131     NaN     NaN  ...  3301.8  3367.2  3431.0  3493.8  3555.9  3617.6
# 132     NaN     NaN  ...  3299.0  3364.7  3428.8  3491.8  3554.1  3615.9
# 133     NaN     NaN  ...  3296.2  3362.2  3426.5  3489.7  3552.2  3614.2
# 134     NaN     NaN  ...  3293.4  3359.7  3424.3  3487.7  3550.4  3612.5
# 135     NaN     NaN  ...  3290.5  3357.2  3422.1  3485.7  3548.5  3610.8
#
#         625     650  Property at pressure   Average
# 0       NaN  3816.4              H at 1.0    29.335
# 1       NaN  3816.3             H at 10.0   191.832
# 2       NaN  3816.2             H at 20.0   251.453
# 3       NaN  3816.2             H at 30.0   289.302
# 4       NaN  3816.1             H at 40.0   317.650
# ..      ...     ...                   ...       ...
# 131  3679.1  3740.4          H at 10600.0  1433.700
# 132  3677.5  3738.9          H at 10800.0  1442.200
# 133  3675.9  3737.5          H at 11000.0  1450.600
# 134  3674.4  3736.0          H at 11200.0  1458.900
# 135  3672.8  3734.6          H at 11400.0  1467.200
#
# [136 rows x 39 columns]
#      Pressure Property  Liq_Sat  Vap_Sat      75     100     125     150  \
# 0         1.0        S   0.1060   8.9767  9.3828  9.5136  9.6365  9.7527
# 1        10.0        S   0.6493   8.1511  8.3168  8.4486  8.5722  8.6888
# 2        20.0        S   0.8321   7.9094  7.9933  8.1261  8.2504  8.3676
# 3        30.0        S   0.9441   7.7695  7.8024  7.9363  8.0614  8.1791
# 4        40.0        S   1.0261   7.6709     NaN  7.8009  7.9268  8.0450
# ..        ...      ...      ...      ...     ...     ...     ...     ...
# 131   10600.0        S   3.4029   5.5835     NaN     NaN     NaN     NaN
# 132   10800.0        S   3.4167   5.5715     NaN     NaN     NaN     NaN
# 133   11000.0        S   3.4304   5.5595     NaN     NaN     NaN     NaN
# 134   11200.0        S   3.4440   5.5476     NaN     NaN     NaN     NaN
# 135   11400.0        S   3.4575   5.5357     NaN     NaN     NaN     NaN
#
#         175     200  ...     475      500     525      550     575      600  \
# 0    9.8629  9.9679  ...     NaN  10.9612     NaN  11.0957     NaN  11.2243
# 1    8.7994  8.9045  ...     NaN   9.8984     NaN  10.0329     NaN  10.1616
# 2    8.4785  8.5839  ...     NaN   9.5784     NaN   9.7130     NaN   9.8416
# 3    8.2903  8.3960  ...     NaN   9.3912     NaN   9.5257     NaN   9.6544
# 4    8.1566  8.2624  ...     NaN   9.2583     NaN   9.3929     NaN   9.5216
# ..      ...     ...  ...     ...      ...     ...      ...     ...      ...
# 131     NaN     NaN  ...  6.4793   6.5652  6.6465   6.7239  6.7983   6.8700
# 132     NaN     NaN  ...  6.4678   6.5542  6.6357   6.7134  6.7880   6.8599
# 133     NaN     NaN  ...  6.4564   6.5432  6.6251   6.7031  6.7779   6.8499
# 134     NaN     NaN  ...  6.4452   6.5324  6.6147   6.6929  6.7679   6.8401
# 135     NaN     NaN  ...  6.4341   6.5218  6.6043   6.6828  6.7580   6.8304
#
#         625      650  Property at pressure  Average
# 0       NaN  11.3476              S at 1.0      NaN
# 1       NaN  10.2849             S at 10.0      NaN
# 2       NaN   9.9650             S at 20.0      NaN
# 3       NaN   9.7778             S at 30.0      NaN
# 4       NaN   9.6450             S at 40.0      NaN
# ..      ...      ...                   ...      ...
# 131  6.9394   7.0067          S at 10600.0      NaN
# 132  6.9294   6.9969          S at 10800.0      NaN
# 133  6.9196   6.9872          S at 11000.0      NaN
# 134  6.9099   6.9777          S at 11200.0      NaN
# 135  6.9004   6.9683          S at 11400.0      NaN
#
# [136 rows x 39 columns]
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   V_data = V_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   U_data = U_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   H_data = H_data.append(df.loc[i], ignore_index=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_3404\1451836857.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   S_data = S_data.append(df.loc[i], ignore_index=True)

# %% [markdown]
# ### 11) Plot the properties (specific volume, specific internal energy, specific enthalpy, specific entropy) vs Pressure for saturated liquid.
#
# Note:
# - Try using the subplot feature of matplotlib(Explore it!!)
# - Provide appropriate title, labels, markersize and other parameters to the plot

# %%
#your code here
figure, axis = plt.subplots(nrows=2, ncols=2,)
V_data.plot(ax=axis[0,0], x="Pressure", y="Liq_Sat",color = 'red', marker='.')
U_data.plot(ax=axis[0,1], x="Pressure", y="Liq_Sat",color = 'green', marker='*')
H_data.plot(ax=axis[1,0], x="Pressure", y="Liq_Sat",color = 'yellow', marker='.')
S_data.plot(ax=axis[1,1], x="Pressure", y="Liq_Sat",color = 'pink')
figure.tight_layout()

# %% [markdown]
# ### 12) Plot the same for saturated vapor.

# %%
#your code here
figure, axis = plt.subplots(nrows=2, ncols=2,)
V_data.plot(ax=axis[0,0], x="Pressure", y="Vap_Sat", marker='.', ms=3)
U_data.plot(ax=axis[0,1], x="Pressure", y="Vap_Sat", marker='*', ms=1)
H_data.plot(ax=axis[1,0], x="Pressure", y="Vap_Sat", marker='.',ms=2)
S_data.plot(ax=axis[1,1], x="Pressure", y="Vap_Sat")
figure.tight_layout()

# %% [markdown]
# ### 13) Plot the specific volume of saturated liquid between 300 kPa and 1500 kPa

# %%
#your code here
data = V_data[ (V_data['Pressure'] >= 300) & (V_data['Pressure'] <= 1500)]
x = data["Pressure"]
y = data["Liq_Sat"]
plt.plot(x,y)
plt.xlabel("Pressure")
plt.ylabel("Specific Volume")
plt.title("V v/s P graph")
plt.show()

# %% [markdown]
# ## Playing with Numpy

# %% [markdown]
# ### 14) Implement the derivative of the sigmoid function using numpy.
#
# Note:
# - Read about sigmoid function over the internet.
# - Input of the function can be a scalar or a numpy array.
#
# **Test Case:**
#
# **Input:**
#
#  [[9, 2, 5, 0, 0]
#
#    [7, 5, 0, 0, 0]]
#
# Output:
#
# [[0.99987661, 0.88079708, 0.99330715, 0.5, 0.5 ]
#
# [0.99908895, 0.99330715, 0.5,  0.5,  0.5 ]]

# %%
#your code here
def derivative(fn):
    return fn*(1-fn)
x = np.array([[9,2,5,0,0], [7,5,0,0,0]])
f = 1/(1+np.exp(-x))
print("Values of sigmoid fn are:", f, '\n')
print("Values of sigmoid derivative are:", derivative(f), '\n')
# Out:
# Values of sigmoid fn are: [[0.99987661 0.88079708 0.99330715 0.5        0.5       ]
#  [0.99908895 0.99330715 0.5        0.5        0.5       ]]
#
# Values of sigmoid derivative are: [[1.23379350e-04 1.04993585e-01 6.64805667e-03 2.50000000e-01
#   2.50000000e-01]
#  [9.10221180e-04 6.64805667e-03 2.50000000e-01 2.50000000e-01
#   2.50000000e-01]]

# %% [markdown]
# ### 15) Define a function which takes in a a numpy array of shape (length, height, depth) and returns a vector of shape (length\*height*depth, 1)

# %%
#your code here
def fn(x):
    l,h,d = x.shape;
    return np.array([l*d*h,1])
arr = np.ones((1,2,3))
print(fn(arr))
# Out:
# [6 1]

# %% [markdown]
# ### 16) Define a softmax function that calculates the softmax for each row of the input x.
#
# Note:
# - The code should work for a row vector and also for matrices of shape (n, m)
#
# **Test Case:**
#
# **Input:**
#
#  [[9 2 5 0 0]
#
#    [7 5 0 0 0]]
#
# Output:
#
# [[9.80897665e-01 8.94462891e-04 1.79657674e-02 1.21052389e-04
#   1.21052389e-04]
#
#  [8.78679856e-01 1.18916387e-01 8.01252314e-04 8.01252314e-04
#   8.01252314e-04]]

# %%
#your code here
def softmax(x):
    i, j = np.shape(x)
    y=np.empty((i,j))
    for k in range(i):
        for l in range(j):
            y[k,l]=np.exp(x[k,l])/(np.sum(np.exp(x[k,:])))
    return y

arr = np.array([[9,2,5,0,0], [7,5,0,0,0]])
print(softmax(arr))
# Out:
# [[9.80897665e-01 8.94462891e-04 1.79657674e-02 1.21052389e-04
#   1.21052389e-04]
#  [8.78679856e-01 1.18916387e-01 8.01252314e-04 8.01252314e-04
#   8.01252314e-04]]
