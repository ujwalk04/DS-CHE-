# %% [markdown]
# # a) |x - x̂|³ , Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

rng = np.random.RandomState(10)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
#plt.scatter(x, y);

#print(x)

#print(rng)

#print(y)

#xlen = len(x)
#print(xlen)

#ylen = len(y)
#print(ylen)

print(x)
print(y)

def loss(y_hat, y):
    l = (y_hat - y)**3
    return l.mean()

def forward_pass(x,m,c):
    return m*x+c

learningrate = 0.01
numiter = 50000

L=[]
N=x.shape[0]
print(N)





m1 = np.random.randn(1)
c1 = np.random.randn(1)

print(m1)
print(c1)


learningrate = 0.01
numiter = 50000

for i in range(numiter):
    
    y_hat=forward_pass(x,m1,c1)
    
   
    
    dm = (3.0/N) *  -np.sum(np.multiply(x,(y - (m1*x +c1))))
   
    dc = (3.0/N) * -np.sum(y - (m1*x + c1))
    
    m1 = m1 -learningrate * dm
    c1 = c1 - learningrate * dm
    if i%10000==0:
        L.append(loss(y_hat,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_hat,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
        
        
        
        
plt.plot(L)

m1,c1
# Out:
# [7.71320643 0.20751949 6.33648235 7.48803883 4.98507012 2.24796646
#  1.98062865 7.60530712 1.69110837 0.88339814 6.85359818 9.53393346
#  0.03948266 5.12192263 8.12620962 6.12526067 7.21755317 2.91876068
#  9.17774123 7.14575783 5.42544368 1.42170048 3.7334076  6.74133615
#  4.41833174 4.34013993 6.17766978 5.13138243 6.50397182 6.01038953
#  8.05223197 5.21647152 9.08648881 3.19236089 0.90459349 3.00700057
#  1.13984362 8.28681326 0.46896319 6.26287148 5.47586156 8.19286996
#  1.9894754  8.56850302 3.51652639 7.54647692 2.95961707 8.8393648
#  3.25511638 1.65015898]
# [ 9.62182172 -4.79765865  7.33382445 10.28824759  5.53529292 -0.65148735
#  -1.06464804 10.49970845 -2.15766234 -2.5250437   9.54942111 14.27144772
#  -2.52633101  6.16130421 11.14014676  6.88834089  9.20292409  0.33579246
#  14.4842676   8.59370564  5.76976518 -2.68589513  3.51299806  7.06411627
#   3.47416431  3.55837418  7.67469599  5.72366775  7.79215375  8.00985153
#  11.41921772  7.9005941  11.66465613  2.00532244 -4.23594555  0.21599232
#  -0.73522817 13.31844067 -5.91825909  7.30296927  5.88587527  9.2540278
#  -1.06987972 12.53034727  2.25031793  8.09856006  2.02694237 12.92327357
#   1.44832073 -2.45357501]
# 50
# [0.53142904]
# [1.09754474]
# no of iterations: 0
# no of iterations: 10000
# no of iterations: 20000
# no of iterations: 30000
# no of iterations: 40000
# (array([0.99313331]), array([1.55924901]))

# %% [markdown]
#  # b) |x - x̂| , Linear Regression

# %%
rng = np.random.RandomState(10)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)

def loss(y_hat, y):
    l = (y_hat - y)
    return l.mean()

def forward_pass(x,m,c):
    return m*x+c

learningrate = 0.01
numiter = 50000

L=[]
N=x.shape[0]
print(N)


m1 = np.random.randn(1)
c1 = np.random.randn(1)

print(m1)
print(c1)


learningrate = 0.01
numiter = 50000

for i in range(numiter):
    
    y_hat=forward_pass(x,m1,c1)
    
   
    
    dm = (1.0/N) *  -np.sum(np.multiply(x,(y - (m1*x +c1))))
   
    dc = (1.0/N) * -np.sum(y - (m1*x + c1))
    
    m1 = m1 -learningrate * dm
    c1 = c1 - learningrate * dm
    if i%10000==0:
        L.append(loss(y_hat,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_hat,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
        
        
plt.plot(L)  

m1,c1
# Out:
# 50
# [-0.19474148]
# [1.94254209]
# no of iterations: 0
# no of iterations: 10000
# no of iterations: 20000
# no of iterations: 30000
# no of iterations: 40000
# (array([0.78407741]), array([2.92136097]))

# %% [markdown]
# # c) |x - x̂|⁴, Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(42)
X = np.random.rand(1000,1)
y = 5*((X)**(2)) + np.random.rand(1000,1)

#ynew = y[-50:] 

#print(xlen)
#print(ylen)

#ynewlen = len(ynew)
#print(ynewlen)


#print(x)
#print(y)

#plt.scatter(x, ynew)
#plt.show


def loss(y, y_hat):
    loss = np.mean((y_hat - y)**4)
    return loss


def gradients(X, y, y_hat):
    
    # X --> Input.
    # y --> true/target value.
    # y_hat --> hypothesis
    # w --> weights (parameter).
    # b --> bias (parameter).
    
    # m-> number of training examples.
    m = X.shape[0]
    
    # Gradient of loss w.r.t weights.
    dw = (1/m)*np.dot(X.T, (y_hat - y))
    
    # Gradient of loss w.r.t bias.
    db = (1/m)*np.sum((y_hat - y)) 
    
    return dw, db

def x_transform(X, degrees):
    
    
    # degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    
    t = X.copy()
    
    # Appending columns of higher degrees to X.
    for i in degrees:
        X = np.append(X, t**i, axis=1)
            
    return X

def train(X, y, bs, degrees, epochs, lr):
    
   
    # bs --> Batch Size.
    
    # degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    
    # Adding features to input X.
    x = x_transform(X, degrees)
    
    # m-> number of training examples
    # n-> number of features 
    m, n = x.shape
    
    # Initializing weights and bias to zeros.
    w = np.zeros((n,1))
    b = 0
    
    
    y = y.reshape(m,1)
    
    
    losses = []
    
    # Training loop.
    for epoch in range(epochs):
        for i in range((m-1)//bs + 1):
            
            # Defining batches.
            start_i = i*bs
            end_i = start_i + bs
            xb = x[start_i:end_i]
            yb = y[start_i:end_i]
            
            # Calculating hypothesis
            y_hat = np.dot(xb, w) + b
            
            
            dw, db = gradients(xb, yb, y_hat)
            
            
            w -= lr*dw
            b -= lr*db
        
        
        l = loss(y, np.dot(x, w) + b)
        losses.append(l)
        
   
    return w, b, losses


# Predicting function.
def predict(X, w, b, degrees):
    
    
    # b --> bias (parameter).
    #degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    # Adding degrees to input X.
    x1 = x_transform(X, degrees)
    
    
    return np.dot(x1, w) + b


w, b, l = train(X, y, bs=100, degrees=[2], epochs=1000,
                lr=0.01)
# Plotting
fig = plt.figure(figsize=(8,6))
plt.plot(X, y, 'y.')
plt.plot(X, predict(X, w, b, [2]), 'r.')
plt.legend(["Data", "Polynomial predictions"])
plt.xlabel('X - Input')
plt.ylabel('y - target / true')
plt.title('Polynomial Regression')
plt.show()


plt.plot(l)

# %% [markdown]
# # d) |x - x̂|7, Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(42)
X = np.random.rand(1000,1)
y = 5*((X)**(2)) + np.random.rand(1000,1)

#ynew = y[-50:] 

#print(xlen)
#print(ylen)

#ynewlen = len(ynew)
#print(ynewlen)


#print(x)
#print(y)

#plt.scatter(x, ynew)
#plt.show


def loss(y, y_hat):
    loss = np.mean((y_hat - y)**7)
    return loss


def gradients(X, y, y_hat):
    
    # X --> Input.
    # y --> true/target value.
    # y_hat --> hypothesis
    # w --> weights (parameter).
    # b --> bias (parameter).
    
    # m-> number of training examples.
    m = X.shape[0]
    
    # Gradient of loss w.r.t weights.
    dw = (1/m)*np.dot(X.T, (y_hat - y))
    
    # Gradient of loss w.r.t bias.
    db = (1/m)*np.sum((y_hat - y)) 
    
    return dw, db

def x_transform(X, degrees):
    
    
    # degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    
    t = X.copy()
    
    # Appending columns of higher degrees to X.
    for i in degrees:
        X = np.append(X, t**i, axis=1)
            
    return X

def train(X, y, bs, degrees, epochs, lr):
    
   
    # bs --> Batch Size.
    
    # degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    
    # Adding features to input X.
    x = x_transform(X, degrees)
    
    # m-> number of training examples
    # n-> number of features 
    m, n = x.shape
    
    # Initializing weights and bias to zeros.
    w = np.zeros((n,1))
    b = 0
    
    
    y = y.reshape(m,1)
    
    
    losses = []
    
    # Training loop.
    for epoch in range(epochs):
        for i in range((m-1)//bs + 1):
            
            # Defining batches.
            start_i = i*bs
            end_i = start_i + bs
            xb = x[start_i:end_i]
            yb = y[start_i:end_i]
            
            # Calculating hypothesis
            y_hat = np.dot(xb, w) + b
            
            
            dw, db = gradients(xb, yb, y_hat)
            
            
            w -= lr*dw
            b -= lr*db
        
        
        l = loss(y, np.dot(x, w) + b)
        losses.append(l)
        
   
    return w, b, losses


# Predicting function.
def predict(X, w, b, degrees):
    
    
    # b --> bias (parameter).
    #degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    # Adding degrees to input X.
    x1 = x_transform(X, degrees)
    
    
    return np.dot(x1, w) + b


w, b, l = train(X, y, bs=100, degrees=[2], epochs=1000,
                lr=0.01)
# Plotting
fig = plt.figure(figsize=(8,6))
plt.plot(X, y, 'y.')
plt.plot(X, predict(X, w, b, [2]), 'r.')
plt.legend(["Data", "Polynomial predictions"])
plt.xlabel('X - Input')
plt.ylabel('y - target / true')
plt.title('Polynomial Regression')
plt.show()


plt.plot(l)
