# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rng = np.random.RandomState()
x = 10 * rng.rand(50)
y = 3*x - 4 + rng.randn(50)
plt.scatter(x, y);

# %%
rng = np.random.RandomState()
x_p = 10 * rng.rand(50)
y_p = x_p**2 - 5*x_p + 6 + rng.randn(50)
plt.scatter(x_p, y_p);

# %%
def loss_1(y_new, y):
    l = np.abs((y_new - y)**3)/3
    return l.mean()

# %%
def loss_2(y_new, y):
    m = np.abs(y_new - y)
    return m.mean()

# %%
def loss_3(y_new, y):
    n = (y_new - y)**4 /4
    return n.mean()

# %%
def loss_4(y_new, y):
    o = np.abs(y_new - y)**7 /7
    return o.mean()

# %%
L_1=[]
L_2=[]
L_3=[]
L_4=[]
N=x.shape[0]

# %%
def forward_pass(x,m,c):
    return m*x+c

# %%
def forward_pass_p(x,a,b,e):
    a*x**2 + b*x + e

# %%
m = np.random.randn(1)
a = np.random.randn(1)
b = np.random.randn(1)
m,a,b
# Out:
# (array([0.32167626]), array([-1.18290388]), array([-1.25379754]))

# %%
m1 = np.random.randn(1)
c1 = np.random.randn(1)

rate = 0.01
par = 40000

for i in range(par):
    y_new=forward_pass(x,m1,c1)

    dm = (1.0/N) *  -np.sum(np.multiply(x,(y - (m1*x +c1))))
   
    dc = (1.0/N) * -np.sum(y - (m1*x + c1))
    
    m1 = m1 - rate * dm
    c1 = c1 - rate * dm
    if i%4000==0:
        L_1.append(loss(y_new,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_new,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 4000
# no of iterations: 8000
# no of iterations: 12000
# no of iterations: 16000
# no of iterations: 20000
# no of iterations: 24000
# no of iterations: 28000
# no of iterations: 32000
# no of iterations: 36000

# %%
m2 = np.random.randn(1)
c2 = np.random.randn(1)

rate = 0.001
par = 40000

for i in range(par):
    y_new=forward_pass(x,m2,c2)

    dm = (1.0/N) *  -np.sum(x)
   
    dc = (1.0/N) * -np.sum(1)
    
    m2 = m2 - rate * dm
    c2 = c2 - rate * dm
    if i%4000==0:
        L_2.append(loss(y_new,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_new,'r*')
    #plt.plot(x,m2*x+c2,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 4000
# no of iterations: 8000
# no of iterations: 12000
# no of iterations: 16000
# no of iterations: 20000
# no of iterations: 24000
# no of iterations: 28000
# no of iterations: 32000
# no of iterations: 36000

# %%
plt.plot(L_1,'green')
plt.plot(L_2,'blue')

# %%
m1,c1
# Out:
# (array([1.83405468]), array([-0.24758552]))

# %%
m2,c2
# Out:
# (array([1.97435789]), array([-0.394973]))
