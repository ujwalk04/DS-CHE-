# %%
### part A

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
rng = np.random.RandomState(10)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x, y);

# %%
def loss(y_hat, y):
    l = (y_hat - y)** 3  / 2
    return l.mean()

# %%
x.shape
# Out:
# (50,)

# %%
m,c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6880\2271313786.py in <module>
# ----> 1 m,c
#
# NameError: name 'c' is not defined

# %%
L=[]
N=x.shape[0]

# %%
def forward_pass(x,m,c):
    return m*x+c

# %%
m = np.random.randn(1)
m
# Out:
# array([-0.85068436])

# %%
m1 = np.random.randn(1)
c1 = np.random.randn(1)

# Hyperparameters
learningrate = 0.01
numiter = 50000

for i in range(numiter):
    # forward pass
    y_hat=forward_pass(x,m1,c1)
    # Loss
   
    # Gradient
    dm = (2.0/N) *  -np.sum(np.multiply(x,(y - (m1*x +c1))))
   
    dc = (2.0/N) * -np.sum(y - (m1*x + c1))
    
    m1 = m1 -learningrate * dm
    c1 = c1 - learningrate * dm
    if i%5000==0:
        L.append(loss(y_hat,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_hat,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 500
# no of iterations: 1000
# no of iterations: 1500
# no of iterations: 2000
# no of iterations: 2500
# no of iterations: 3000
# no of iterations: 3500
# no of iterations: 4000
# no of iterations: 4500
# no of iterations: 5000
# no of iterations: 5500
# no of iterations: 6000
# no of iterations: 6500
# no of iterations: 7000
# no of iterations: 7500
# no of iterations: 8000
# no of iterations: 8500
# no of iterations: 9000
# no of iterations: 9500
# no of iterations: 10000
# no of iterations: 10500
# no of iterations: 11000
# no of iterations: 11500
# no of iterations: 12000
# no of iterations: 12500
# no of iterations: 13000
# no of iterations: 13500
# no of iterations: 14000
# no of iterations: 14500
# no of iterations: 15000
# no of iterations: 15500
# no of iterations: 16000
# no of iterations: 16500
# no of iterations: 17000
# no of iterations: 17500
# no of iterations: 18000
# no of iterations: 18500
# no of iterations: 19000
# no of iterations: 19500
# no of iterations: 20000
# no of iterations: 20500
# no of iterations: 21000
# no of iterations: 21500
# no of iterations: 22000
# no of iterations: 22500
# no of iterations: 23000
# no of iterations: 23500
# no of iterations: 24000
# no of iterations: 24500
# no of iterations: 25000
# no of iterations: 25500
# no of iterations: 26000
# no of iterations: 26500
# no of iterations: 27000
# no of iterations: 27500
# no of iterations: 28000
# no of iterations: 28500
# no of iterations: 29000
# no of iterations: 29500
# no of iterations: 30000
# no of iterations: 30500
# no of iterations: 31000
# no of iterations: 31500
# no of iterations: 32000
# no of iterations: 32500
# no of iterations: 33000
# no of iterations: 33500
# no of iterations: 34000
# no of iterations: 34500
# no of iterations: 35000
# no of iterations: 35500
# no of iterations: 36000
# no of iterations: 36500
# no of iterations: 37000
# no of iterations: 37500
# no of iterations: 38000
# no of iterations: 38500
# no of iterations: 39000
# no of iterations: 39500
# no of iterations: 40000
# no of iterations: 40500
# no of iterations: 41000
# no of iterations: 41500
# no of iterations: 42000
# no of iterations: 42500
# no of iterations: 43000
# no of iterations: 43500
# no of iterations: 44000
# no of iterations: 44500
# no of iterations: 45000
# no of iterations: 45500
# no of iterations: 46000
# no of iterations: 46500
# no of iterations: 47000
# no of iterations: 47500
# no of iterations: 48000
# no of iterations: 48500
# no of iterations: 49000
# no of iterations: 49500

# %%
plt.plot(L)

# %%
m1,c1
# Out:
# (array([1.11455118]), array([0.81868052]))

# %%
### PART B

# %%
def loss(y_hat, y):
    l = (y_hat - y)  / 2
    return l.mean()

# %%
x.shape

# %%
m,c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6880\2271313786.py in <module>
# ----> 1 m,c
#
# NameError: name 'c' is not defined

# %%
L=[]
N=x.shape[0]

# %%
def forward_pass(x,m,c):
    return m*x+c

# %%
m = np.random.randn(1)
m
# Out:
# array([-0.39431291])

# %%
m1 = np.random.randn(1)
c1 = np.random.randn(1)

# Hyperparameters
learningrate = 0.01
numiter = 50000

for i in range(numiter):
    # forward pass
    y_hat=forward_pass(x,m1,c1)
    # Loss
   
    # Gradient
    dm = (2.0/N) *  -np.sum(np.multiply(x,(y - (m1*x +c1))))
   
    dc = (2.0/N) * -np.sum(y - (m1*x + c1))
    
    m1 = m1 -learningrate * dm
    c1 = c1 - learningrate * dm
    if i%5000==0:
        L.append(loss(y_hat,y))
        print ("no of iterations:",i )
        plt.plot(x,y,'go')
        plt.plot(x,y_hat,'r*')
    #plt.plot(x,m1*x+c1,'r*')
        plt.ylabel('Data')
        plt.show()
# Out:
# no of iterations: 0
# no of iterations: 5000
# no of iterations: 10000
# no of iterations: 15000
# no of iterations: 20000
# no of iterations: 25000
# no of iterations: 30000
# no of iterations: 35000
# no of iterations: 40000
# no of iterations: 45000

# %%
plt.plot(L)

# %%
### part c

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
X = np.random.rand(1000,1)
y = 0.5*((X)**(2)) + np.random.rand(1000,1)

# %%
def loss(y, y_hat):
    
    # y --> true/target value.
    # y_hat --> hypothesis
    
    #Calculating loss.
    loss = np.mean((y_hat - y)**4)
    return loss

# %%
# Calulating gradient of loss w.r.t parameters(weights and bias).
def gradients(X, y, y_hat):
    
    # X --> Input.
    # y --> true/target value.
    # y_hat --> hypothesis
    # w --> weights (parameter).
    # b --> bias (parameter).
    
    # m-> number of training examples.
    m = X.shape[0]
    
    # Gradient of loss w.r.t weights.
    dw = (1/m)*np.dot(X.T, (y_hat - y))
    
    # Gradient of loss w.r.t bias.
    db = (1/m)*np.sum((y_hat - y)) 
    
    return dw, db

# %%
def x_transform(X, degrees):
    
    # X --> Input.
    # degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    # making a copy of X.
    t = X.copy()
    
    # Appending columns of higher degrees to X.
    for i in degrees:
        X = np.append(X, t**i, axis=1)
            
    return X

# %%
def train(X, y, bs, degrees, epochs, lr):
    
    # X --> Input.
    # y --> true/target value.
    # bs --> Batch Size.
    # epochs --> Number of iterations.
    # degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    # lr --> Learning rate.
    
    # Adding features to input X.
    x = x_transform(X, degrees)
    
    # m-> number of training examples
    # n-> number of features 
    m, n = x.shape
    
    # Initializing weights and bias to zeros.
    w = np.zeros((n,1))
    b = 0
    
    # Reshaping y.
    y = y.reshape(m,1)
    
    # Empty list to store losses.
    losses = []
    # Training loop.
    for epoch in range(epochs):
        for i in range((m-1)//bs + 1):
            
            # Defining batches.
            start_i = i*bs
            end_i = start_i + bs
            xb = x[start_i:end_i]
            yb = y[start_i:end_i]
            
            # Calculating hypothesis
            y_hat = np.dot(xb, w) + b
            
            # Getting the gradients of loss w.r.t parameters.
            dw, db = gradients(xb, yb, y_hat)
            
            # Updating the parameters.
            w -= lr*dw
            b -= lr*db
        
        # Calculating loss and appending it in the list.
        l = loss(y, np.dot(x, w) + b)
        losses.append(l)
        
    # returning weights, bias and losses(List).
    return w, b, losses

# %%
# Predicting function.
def predict(X, w, b, degrees):
    
    # X --> Input.
    # w --> weights (parameter).
    # b --> bias (parameter).
    #degrees --> A list, We add X^(value) feature to the input
    #             where value is one of the values in the list.
    
    # Adding degrees to input X.
    x1 = x_transform(X, degrees)
    
    # Returning predictions.
    return np.dot(x1, w) + b
w, b, l = train(X, y, bs=100, degrees=[2], epochs=1000,
                lr=0.01)
# Plotting
fig = plt.figure(figsize=(8,6))
plt.plot(X, y, 'y.')
plt.plot(X, predict(X, w, b, [2]), 'r.')
plt.legend(["Data", "Polynomial predictions"])
plt.xlabel('X - Input')
plt.ylabel('y - target / true')
plt.title('Polynomial Regression')
plt.show()

def r2_score(y, y_hat):
    return 1 - (np.sum((np.array(y_hat)-np.array(y))**2)/
                np.sum((np.array(y)-np.mean(np.array(y)))**2))
# r2_score(y_train, predict(x_train, w, b, [2]))

# %%
### part D

# %%
def loss(y, y_hat):
    
    # y --> true/target value.
    # y_hat --> hypothesis
    
    #Calculating loss.
    loss = np.mean((y_hat - y)**7)
    return loss

# %%
# Calulating gradient of loss w.r.t parameters(weights and bias).
def gradients(X, y, y_hat):
    
    
    m = X.shape[0]
    
    # Gradient 
    dw = (1/m)*np.dot(X.T, (y_hat - y))
    
    # Gradient 
    db = (1/m)*np.sum((y_hat - y)) 
    
    return dw, db

# %%
def x_transform(X, degrees):
    
    
    t = X.copy()
    
    # Appending columns of higher degrees to X.
    for i in degrees:
        X = np.append(X, t**i, axis=1)
            
    return X

# %%
def train(X, y, bs, degrees, epochs, lr):
    
    
    x = x_transform(X, degrees)
    
    
    m, n = x.shape
    
    # Initializing weights and bias to zeros.
    w = np.zeros((n,1))
    b = 0
    
    # Reshaping y.
    y = y.reshape(m,1)
    
    # Empty list to store losses.
    losses = []
    # Training loop.
    for epoch in range(epochs):
        for i in range((m-1)//bs + 1):
            
            # Defining batches.
            start_i = i*bs
            end_i = start_i + bs
            xb = x[start_i:end_i]
            yb = y[start_i:end_i]
            
            # Calculating hypothesis
            y_hat = np.dot(xb, w) + b
            
            # Getting the gradients of loss w.r.t parameters.
            dw, db = gradients(xb, yb, y_hat)
            
            # Updating the parameters.
            w -= lr*dw
            b -= lr*db
        
        # Calculating loss and appending it in the list.
        l = loss(y, np.dot(x, w) + b)
        losses.append(l)
        
    # returning weights, bias and losses(List).
    return w, b, losses

# %%
# Predicting function.
def predict(X, w, b, degrees):
    
    x1 = x_transform(X, degrees)
    
    # Returning predictions.
    return np.dot(x1, w) + b
w, b, l = train(X, y, bs=100, degrees=[2], epochs=1000,
                lr=0.01)
# Plotting
fig = plt.figure(figsize=(8,6))
plt.plot(X, y, 'y.')
plt.plot(X, predict(X, w, b, [2]), 'r.')
plt.legend(["Data", "Polynomial predictions"])
plt.xlabel('X - Input')
plt.ylabel('y - target / true')
plt.title('Polynomial Regression')
plt.show()

def r2_score(y, y_hat):
    return 1 - (np.sum((np.array(y_hat)-np.array(y))**2)/
                np.sum((np.array(y)-np.mean(np.array(y)))**2))
#r2_score(y_train, predict(x_train, w, b, [2]))
