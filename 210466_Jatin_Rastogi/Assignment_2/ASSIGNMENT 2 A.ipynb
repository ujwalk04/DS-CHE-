# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
rng = np.random.RandomState(10)
x = 10 * rng.rand(50)
y = (2 * x - 5 + rng.randn(50))
plt.scatter(x, y);

# %%
x.shape
# Out:
# (50,)

# %%
N=x.shape[0]
N
L=[]

# %%
def result(m1,x,c1):
    return m1*x+c1

# %%
def loss(y,y_hat):
    l=abs((y-y_hat)**3)
    return l.mean()

# %%
m1 = np.random.randn(1)
c1 = np.random.randn(1)
m1,c1
# Out:
# (array([0.28157899]), array([0.0147902]))

# %%
learning_rate = 0.001
total_iter = 50001

# %%
for i in range(total_iter):
    
    y_hat=result(m1,x,c1)
    dm=3/N*np.sum(x*(((m1*x+c1)-y)*abs(m1*x+c1)-y))
    dc=3/N*np.sum(((m1*x+c1)-y)*abs(m1*x+c1)-y)
    m1=m1-dm*learning_rate
    c1=c1-dc*learning_rate
    if i%10000==0:
        L.append(loss(y,y_hat))
        print("total iteration: ",i)
        plt.plot(x,y_hat,"r*")
        plt.plot(x,y,"go")
        
        plt.show()
# Out:
# total iteration:  0
# total iteration:  10000
# total iteration:  20000
# total iteration:  30000
# total iteration:  40000

# %%
m1,c1
# Out:
# (array([2.12595036]), array([-5.09212787]))
