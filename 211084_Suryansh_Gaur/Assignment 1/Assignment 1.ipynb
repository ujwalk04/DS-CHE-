# %% [markdown]
# # DS : CHE

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# **Welcome to your first assignment of SimuTech Winter Project 2022! I hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about properties of superheated vapor.**
#
# The dataset consists of the thermophysical properties: specific volume, specific internal energy, specific enthalpy, specific entropy of superheated vapor.
#
# Pressure is in kPa and Temperature in centigrade. In the dataframe 75, 100, 125 are temperatures.
#
# **There are some interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas and matplotlib!***

# %% [markdown]
# ### 1) Import all the libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2) Read the csv file.

# %%
import csv
with open('superheated_vapor_properties.csv', mode ='r')as file:
   

  csvFile = csv.reader(file)

# %% [markdown]
# ### 3) Display shape of dataframe

# %%
import pandas as pd
data=pd.read_csv('superheated_vapor_properties.csv')
display=data.shape
print(display)
# Out:
# (544, 37)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
print(data.columns)
# Out:
# Index(['Pressure', 'Property', 'Liq_Sat', 'Vap_Sat', '75', '100', '125', '150',
#        '175', '200', '220', '225', '240', '250', '260', '275', '280', '290',
#        '300', '320', '325', '340', '350', '360', '375', '380', '400', '425',
#        '450', '475', '500', '525', '550', '575', '600', '625', '650'],
#       dtype='object')

# %% [markdown]
# ### 5) Display the number of null values in each column of the dataframe

# %%
#your code here
data.isna().sum()
# Out:
# Pressure      0
# Property      0
# Liq_Sat       0
# Vap_Sat       0
# 75          528
# 100         508
# 125         488
# 150         448
# 175         384
# 200         320
# 220         408
# 225         400
# 240         408
# 250         344
# 260         384
# 275         340
# 280         380
# 290         488
# 300          60
# 320         480
# 325         136
# 340         476
# 350          68
# 360         476
# 375         204
# 380         476
# 400           0
# 425         204
# 450           0
# 475         204
# 500           0
# 525         272
# 550           0
# 575         340
# 600           0
# 625         476
# 650           0
# dtype: int64

# %% [markdown]
# ###  6) Print a list of all the unique items in the Property column

# %%
unique=data['Property'].unique()
print(unique)
# Out:
# ['V' 'U' 'H' 'S']

# %% [markdown]
# ### 7) Create a column which contains the Pressure and Property columns, seperated with 'at' (For eg. V at 1, H at 101.325). Using this print the following:
# - Enthalpy at 75 kPa and 573 K
# - Entropy at 493 K and 250 kPa

# %%
a=data['Property']
b=data['Pressure']
df=pd.DataFrame(a,b)
# H at 75kPa and 300 C=3075.1
#S at 250 kPa and 220 C=NaN
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '300'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### 8) Find out the column with the highest number of missing values

# %%
data.count ().idxmin ()
# Out:
# '75'

# %% [markdown]
# ### 9) What is the average enthalpy of Sat. Liq. at all different pressures in the dataset ?

# %%
avg=data.loc[data['Property']=='H','Liq_Sat'].mean()
print(avg)
# Out:
# 936.9707720588237

# %% [markdown]
# ### 10) Separate out the V,U,H,S data from the dataset into V_data, U_data, H_data, S_data

# %%
V_data=data.loc[data['Property']=='V',]
U_data=data.loc[data['Property']=='U',]
H_data=data.loc[data['Property']=='H',]
S_data=data.loc[data['Property']=='S',]
print(V_data,U_data,H_data,S_data)
# Out:
#      Pressure Property  Liq_Sat     Vap_Sat        75       100       125  \
# 0         1.0        V    1.000  129200.000  160640.0  172180.0  183720.0
# 4        10.0        V    1.010   14670.000   16030.0   17190.0   18350.0
# 8        20.0        V    1.017    7649.800    8000.0    8584.7    9167.1
# 12       30.0        V    1.022    5229.300    5322.0    5714.4    6104.6
# 16       40.0        V    1.027    3993.400       NaN    4279.2    4573.3
# ..        ...      ...      ...         ...       ...       ...       ...
# 524   10600.0        V    1.474      16.778       NaN       NaN       NaN
# 528   10800.0        V    1.481      16.385       NaN       NaN       NaN
# 532   11000.0        V    1.489      16.006       NaN       NaN       NaN
# 536   11200.0        V    1.496      15.639       NaN       NaN       NaN
# 540   11400.0        V    1.504      15.284       NaN       NaN       NaN
#
#           150       175       200  ...     425         450     475  \
# ...

# %% [markdown]
# ### 11) Plot the properties (specific volume, specific internal energy, specific enthalpy, specific entropy) vs Pressure for saturated liquid.
#
# Note:
# - Try using the subplot feature of matplotlib(Explore it!!)
# - Provide appropriate title, labels, markersize and other parameters to the plot

# %%
fig,axes=plt.subplots(2,2)
V_data.plot(ax=axes[0,0],x='Pressure',y='Liq_Sat',marker=".")
U_data.plot(ax=axes[0,1],x='Pressure',y='Liq_Sat',marker="+")
H_data.plot(ax=axes[1,0],x='Pressure',y='Liq_Sat',marker="_")
S_data.plot(ax=axes[1,1],x='Pressure',y='Liq_Sat',marker="*")
axes[0,0].set_title('Specific volume vs Pressure')
axes[0,1].set_title('Specific Internal energy vs Pressure')
axes[1,0].set_title('Specific Enthalpy vs Pressure')
axes[1,1].set_title('Specific Entropy vs Pressure')
axes[0,0].set_ylabel('Specific volume')
axes[0,1].set_ylabel('Specific Internal Energy')
axes[1,0].set_ylabel('Specific enthalpy')
axes[1,1].set_ylabel('Specific entropy')
axes[0,0].set_xlabel('Pressure')
axes[0,1].set_xlabel('Pressure')
axes[1,0].set_xlabel('Pressure')
axes[1,1].set_xlabel('Pressure')
# Out:
# Text(0.5, 0, 'Pressure')

# %% [markdown]
# ### 12) Plot the same for saturated vapor.

# %%
fig,axes=plt.subplots(2,2)
V_data.plot(ax=axes[0,0],x='Pressure',y='Vap_Sat',marker=".")
U_data.plot(ax=axes[0,1],x='Pressure',y='Vap_Sat',marker="+")
H_data.plot(ax=axes[1,0],x='Pressure',y='Vap_Sat',marker="_")
S_data.plot(ax=axes[1,1],x='Pressure',y='Vap_Sat',marker="*")
axes[0,0].set_title('Specific volume vs Pressure')
axes[0,1].set_title('Specific Internal energy vs Pressure')
axes[1,0].set_title('Specific Enthalpy vs Pressure')
axes[1,1].set_title('Specific Entropy vs Pressure')
axes[0,0].set_ylabel('Specific volume')
axes[0,1].set_ylabel('Specific Internal Energy')
axes[1,0].set_ylabel('Specific enthalpy')
axes[1,1].set_ylabel('Specific entropy')
axes[0,0].set_xlabel('Pressure')
axes[0,1].set_xlabel('Pressure')
axes[1,0].set_xlabel('Pressure')
axes[1,1].set_xlabel('Pressure')
# Out:
# Text(0.5, 0, 'Pressure')

# %% [markdown]
# ### 13) Plot the specific volume of saturated liquid between 300 kPa and 1500 kPa

# %%
V_data.plot(x='Pressure',y='Liq_Sat',markersize="20",marker="+")
plt.ylabel("Specific Volume")
plt.title("Specific volume vs Pressure")
plt.xlim(300,1500)
# Out:
# (300.0, 1500.0)

# %% [markdown]
# ## Playing with Numpy

# %% [markdown]
# ### 14) Implement the derivative of the sigmoid function using numpy.
#
# Note:
# - Read about sigmoid function over the internet.
# - Input of the function can be a scalar or a numpy array.
#
# **Test Case:**
#
# **Input:**
#
#  [[9, 2, 5, 0, 0]
#
#    [7, 5, 0, 0, 0]]
#
# Output:
#
# [[0.99987661, 0.88079708, 0.99330715, 0.5, 0.5 ]
#
# [0.99908895, 0.99330715, 0.5,  0.5,  0.5 ]]

# %%
import numpy as np
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x))
ans=np.array([[9,2,5,0,0],[7,5,0,0,0]])
sigmoid(ans)
# Out:
# array([[0.99987661, 0.88079708, 0.99330715, 0.5       , 0.5       ],
#        [0.99908895, 0.99330715, 0.5       , 0.5       , 0.5       ]])

# %% [markdown]
# ### 15) Define a function which takes in a a numpy array of shape (length, height, depth) and returns a vector of shape (length\*height*depth, 1)

# %%
import numpy as np
def lhd(length,height,depth):
    return length*height*depth,1
lhd(1,2,3)
# Out:
# (6, 1)

# %% [markdown]
# ### 16) Define a softmax function that calculates the softmax for each row of the input x.
#
# Note:
# - The code should work for a row vector and also for matrices of shape (n, m)
#
# **Test Case:**
#
# **Input:**
#
#  [[9 2 5 0 0]
#
#    [7 5 0 0 0]]
#
# Output:
#
# [[9.80897665e-01 8.94462891e-04 1.79657674e-02 1.21052389e-04
#   1.21052389e-04]
#
#  [8.78679856e-01 1.18916387e-01 8.01252314e-04 8.01252314e-04
#   8.01252314e-04]]

# %%
import numpy as np
def softmax(x):
    return np.exp(x)/sum(np.exp(x))
x=np.array([9,2,5,0,0])
print(softmax(x))
y=np.array([7,5,0,0,0])
print(softmax(y))
# Out:
#   File "C:\Users\surya\AppData\Local\Temp\ipykernel_16204\3028351965.py", line 4
#     x= np.array([[9,2,5,0,0]])
#     ^
# SyntaxError: invalid syntax
